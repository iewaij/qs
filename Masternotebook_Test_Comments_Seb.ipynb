# %% [markdown]
# **Quantitative Trading and Analysis with Python: Course Project**
#
# Submitted by:\
# Jiawei Li (XXX)\
# Sebastian Sydow (8316620)\
# Strahinja Trenkic (XXX)\
# Xiaoyi Zhou (XXX)\
# Date: 30th March 2022

# %% [markdown]
# # Introduction
#
# In this notebook, we created several functions, which perform the necessary (sub-)steps for the given task. This allowed us to easily reproduce results or change certain parameters. Please refer to the docstrings at the beginning of and the comments within the functions for further explanations.
#
# **Note:** Some of the explanations or quality checks in this notebook might seem too exhaustive or dispensable for the given task. Nevertheless, these explanations and quality checks were added as they facilitated in the process of understanding the concepts and shall serve as a future point of reference for us. Moreover, this notebook used some of the code provided during the lectures of the course *Quantitative Trading and Analysis with Python* (M.Sc.) at the Frankfurt School of Finance and Management.

# %% [markdown]
# # Preliminaries and Imports
# In the following cell, the necessary packages and libraries are imported.

# %%
# access to different databases
import pandas_datareader as web
import quandl as quandl
import wrds as wrds

# storage and operations
import pandas as pd
import numpy as np
import datetime
from pathlib import Path
from tqdm import tqdm
import time

# statistics and regression
import statsmodels.api as sm
from statsmodels.regression.rolling import RollingOLS
from sklearn.linear_model import Lasso
from scipy.stats.mstats import winsorize
import quantstats as qs
from scipy.optimize import minimize 
from sklearn import metrics
from scipy import stats

# indicators
import ta as ta
from ta.momentum import KAMAIndicator
from ta.momentum import PercentagePriceOscillator
from ta.momentum import ROCIndicator
from ta.momentum import RSIIndicator
from ta.trend import AroonIndicator
from ta.trend import EMAIndicator
from ta.trend import MACD
from pandas.tseries.offsets import BDay
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from statsmodels.stats.outliers_influence import variance_inflation_factor

# plotting
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.pyplot import figure
from matplotlib.axis import Axis
import matplotlib.dates as mdates 
# %matplotlib inline

# warning
import warnings
warnings.filterwarnings("ignore")

# unzipping zip-files
from zipfile import ZipFile

# %% [markdown]
# # Data Imports and Preperations
# In the next cell, the data of different data sources is loaded and preprocessed. The data for the generalized lower bounds for the expected excess simple returns (`df_glb`) and  risk-neutral skewness (`df_mfis`) were provided by [Grigory Vilkov](https://www.vilkov.net/index.html) and retrieved from [here](https://osf.io/z2486/). <br>

# %%
# define an useful path
path = Path('/Users/sebastiansydow/13_Quant_Trading/Group_Project')
# path = Path(r'\Users\Strahinja\Desktop\books_Germany\Quant\Group_Project')
# stocks
input_stocks = path / 'permno_selection.csv'
# link betweeen CRSP (permno) and Option Metrics (SECID)
link_permno_secid = path / 'daily_permno_secid_cusip_link.csv.zip'
# glb
glb = path / 'glb_daily.csv'
# model-free implied skewness (MFIS)
mfis = path / 'mfis.csv'
# Save a hdf locally for easier modeling
hdf_path = path / 'factors.h5'
#quandl key
quandl_key = path / 'quandl_key.xlsx'
#quandl_key = 'XWVLTpJSLyiA8s66Fh8x'
# import stocks from S&P 500 into a pandas dataframe
df_input_stocks = pd.read_csv(input_stocks)
# glb
df_glb = pd.read_csv(glb)
## rename column
df_glb = df_glb.rename(columns={"id": "permno"})
## transfrom data type
df_glb['date'] = pd.to_datetime(df_glb['date'])
# mfis
df_mfis = pd.read_csv(mfis)
## rename column
df_mfis = df_mfis.rename(columns={"id": "permno"})
## transfrom data type
df_mfis['date'] = pd.to_datetime(df_mfis['date'])
# instantiate zip-file
zip_file = ZipFile(link_permno_secid)
# load linking table
df_link_permno_secid = pd.read_csv(zip_file.open('daily_permno_secid_cusip_link.csv'))

# %% [markdown]
# ## Daily Stock Returns, Market Capitalization and Value Weights
# In the next cell, we created a function to retrieve the daily stock returns, daily stock prices and daily shares outstanding for the companies in `df_input_stocks`.

# %%
def retrieve_stock_data(df_input, date_start, date_end, wrds_username):
    """
    This function retrieves the permno, cusip return, price, shares outstanding and market value of each stock
    on each day.
    
    Parameters
    ----------
    df_input: dataframe
        The dataframe storing the information about the stocks.
        
    date_start: str
        First date of data retrieval.
        
    date_end: str
        Last date of data retrieval.
    
    wrds_username: str
        Username of the wrds-account used for the data retrieval.
        
    Returns
    -------
    This functions returns the information for each stock on each day 
    as well as the weightage of each stock on each day by market value in a dataframe. 
    """
    
    # Download stock data
    ## establish WRDS connection
    db = wrds.Connection(wrds_username=wrds_username)
    
    # create query to load the returns, prices and shares outstanding for S&P 500 companies from 1999/01
    sql_wrds = """
            select distinct date, 
                            permno,
                            cusip, 
                            ret, 
                            abs(prc) as prc, 
                            shrout,
                            abs(prc)*shrout/1000 as mktval
            from crsp.dsf 
            where permno in %(permno)s and date>=%(start)s and date<=%(end)s
            order by date
            """

    # define the parameters
    params = {}
    params['start'] = date_start
    params['end'] = date_end
    params['permno'] = tuple(df_input.permno.unique().astype(str))

    # retrieve the data from wrds
    df_stock_data = db.raw_sql(sql_wrds, params = params)

    # change type of entries in the columns start and ending
    df_stock_data['date']  = pd.to_datetime(df_stock_data['date'])
    
    # shift market_val by 1 day
    df_stock_data.loc[:,'mktval_shifted'] = df_stock_data.groupby(['permno'])['mktval'].shift(1)
    
    # calculate weight of each stock on each day
    ## dataframe with total market value on each day
    df_ttl_mkcap = df_stock_data[['date', 'mktval_shifted']].groupby('date').sum().rename(columns={"mktval_shifted": "ttl_mktval"})
    ## merge with df_stock_data
    df_stock_data = pd.merge(df_stock_data, df_ttl_mkcap, how='left', on=['date'])
    ## calculate weightage
    df_stock_data['weightage_pct'] =  df_stock_data['mktval_shifted'] / df_stock_data["ttl_mktval"]
    ## drop columns
    df_stock_data.drop(columns = {'shrout', 'mktval', 'mktval_shifted', 'ttl_mktval'}, inplace = True)
    
    return df_stock_data.sort_values(by=['date']).reset_index(drop=True)

# %% [markdown]
# ## Fama-French-Factors
# In the next cell, we created a function to download the data for the four-factor model (daily) from the Ken French data library.

# %%
def download_ffm(date_start, date_end):
    """
    This function download the data for the four-factor model (daily) from the Ken French data library.

    Parameters
    ----------
    date_start: str
        First date of data retrieval.
        
    date_end: str
        Last date of data retrieval.
    
    Returns
    -------
    This functions returns the data for the four-factor model (daily) from the Ken French data library
    in a dataframe. 
    """
    
    # start of time period 
    startdt = datetime.datetime(int(date_start[:4]),
                                int(date_start[5:7]),
                                int(date_start[8:]))
    
    # end of time period                            
    enddt = datetime.datetime(int(date_end[:4]),
                              int(date_end[5:7]),
                              int(date_end[8:]))

    # define which dataset are to be downloaded
    d1 = web.DataReader('F-F_Research_Data_Factors_daily','famafrench',start=startdt, end=enddt)
    d2 = web.DataReader('F-F_Momentum_Factor_daily','famafrench',start=startdt, end=enddt)

    # key is 0 -> get returns data
    # divide by 100 to get the returns
    df_ff_3factor = d1[0]/100

    # add momentum factor with an outer-join
    # outer-join: keep all data -> union
    df_ff_4factor = df_ff_3factor.join(d2[0]/100, how = 'outer')

    # reset index for merge later
    df_ff_4factor = df_ff_4factor.reset_index()

    # change columns to be small letters and get rid of white-spaces
    df_ff_4factor.columns = [z.lower().strip() for z in df_ff_4factor.columns]

    # rename column
    df_ff_4factor.rename(columns = {'mkt-rf':'mktrf'}, inplace = True)

    # change order of dataframe
    df_ff_4factor = df_ff_4factor.loc[:,['date', 'mktrf', 'smb', 'hml', 'mom', 'rf']]
                              
    return df_ff_4factor

# %% [markdown]
# ## Quandl Data
#
# In the next cell, we created a function to download data from quandl, among others:
#
# **Crude Oil Prices**
# - [WTI Spot Price](https://data.nasdaq.com/data/EIA/PET_RWTC_D-cushing-ok-wti-spot-price-fob-daily)
#
# **Treasury Yields**
# - [US Treasury Yields](https://data.nasdaq.com/data/USTREASURY/YIELD-treasury-yield-curve-rates)
#
# **Gold**
# - [LBMA/GOLD](https://data.nasdaq.com/data/LBMA/GOLD-gold-price-london-fixing)

# %%
def get_quandl_data(quandl_key):
    """
    This function download the data from quandl, which can later be utilized to construct factors.

    Parameters
    ----------
    quandl_key: path
        Path to an excel-file, which stores the quandl-key in the first cell.
    
    Returns
    -------
    This functions returns three dataframes: 
    - Daily WTI Spot Prices
    - Daily yield difference between 10year yield and 1year yield of US treasuries
    - Daily price of gold
    """
    
    # retrieve quandl key
    temp = pd.read_excel(quandl_key)
    # configure quandl
    quandl.ApiConfig.api_key = temp.iloc[0,0]
    
    # Crude Oil
    df_crude_oil = quandl.get("EIA/PET_RWTC_D")
    # calculate daily returns
    df_crude_oil = df_crude_oil.pct_change(1)
    # reset_index
    df_crude_oil.reset_index(inplace=True)
    # rename column
    df_crude_oil.rename(columns={"Value": "ret_crude_oil", "Date": "date"}, inplace=True)
    
    # Treasury Yields
    df_treasury_yield = quandl.get("USTREASURY/YIELD")
    # drop columns
    df_treasury_yield.drop(labels=['1 MO', '2 MO', '3 MO', '6 MO', '2 YR', '3 YR', '5 YR', '7 YR', '20 YR', '30 YR'], axis=1, inplace=True)
    # calculate difference between 10year yield and 1year yield
    df_treasury_yield['yield_dif_10y_1y'] = df_treasury_yield['10 YR'] - df_treasury_yield['1 YR']
    # drop columns
    df_treasury_yield.drop(labels=['1 YR', '10 YR'], axis=1, inplace=True)
    # reset_index
    df_treasury_yield.reset_index(inplace=True)
    # rename column
    df_treasury_yield.rename(columns={"Date": "date"}, inplace=True)
    
    # Gold
    df_gold = quandl.get("LBMA/GOLD")
    # drop columns
    df_gold.drop(labels=['USD (PM)','GBP (AM)', 'GBP (PM)', 'EURO (AM)', 'EURO (PM)'], axis=1, inplace=True)
    # calculate daily returns
    df_gold = df_gold.pct_change(1)
    # reset_index
    df_gold.reset_index(inplace=True)
    # rename column
    df_gold.rename(columns={"USD (AM)": "ret_gold", "Date": "date"}, inplace=True)
    
    return df_crude_oil, df_treasury_yield, df_gold

# %% [markdown]
# ## Exchange Rate
#
# Data about exchange rates were retrieved from the St. Louis FED with the function `get_fx_data`.
# - [Exchange Rates ST. Louis FRED](https://fred.stlouisfed.org/categories/15)
# - [Nominal Emerging Market Economies U.S. Dollar Index](https://fred.stlouisfed.org/series/DTWEXEMEGS), only available from 2006 onwards
# - [Real Emerging Market Economies Dollar Index](https://fred.stlouisfed.org/series/RTWEXEMEGS), only available from 2006 onwards

# %%
def get_fx_data(symbol, start_date):
    """
    This function downloads the data about exchange rates from the ST. Louis FED.

    Parameters
    ----------
    symbol: symbol
        Identifier of the data provided by the St. Louis FED.
        
    start_date: datetime
        First date of data retrieval.
    
    Returns
    -------
    This functions returns the dataframe with the daily returns of the forex data. 
    """
    # get data
    df_fx = data.DataReader(symbol, 'fred', start_date)
    # calculate daily returns
    df_fx = df_fx.pct_change(1)
    # reset index
    df_fx.reset_index(inplace=True)
    # rename
    df_fx.rename(columns={'DATE': 'date', symbol: 'fx_rates'}, inplace=True)
    
    return df_fx

# %% [markdown]
# ## Calculate Excess Return

# %%
def calc_excess_return(df, minuend, subtrahend):
    """
    This function calculates the excess return.

    Parameters
    ----------
    df: dataframe
        Identifier of the data provided by the St. Louis FED.
        
    minuend: str
        Column storing data about the minuend.
        
    subtrahend: str
        Column storing data about the subtrahend.
    
    Returns
    -------
    This functions returns the dataframe with an additional column for the excess return. 
    """
    # calculate excess return
    df['excess_return'] = df[minuend]-df[subtrahend]
    return df

# %% [markdown]
# ## Perfrom Data Preparation

# %%
def data_prep(df_input, date_start, date_end, df_link, wrds_username, minuend, subtrahend, quandl_key):
    """
    This function calls the previously created functions to load and pre-process the data.

    Parameters
    ----------
    df_input: dataframe
        The dataframe storing the information about the stocks.
        
    date_start: str
        First date of data retrieval.
        
    date_end: str
        Last date of data retrieval.
        
    df_link: dataframe
        The dataframe storing the mapping between CRSP [permno] and OptionMetrics [secid] identifiers.
    
    wrds_username: str
        Username of the wrds-account used for the data retrieval.
        
    minuend: str
        Column storing data about the minuend.
        
    subtrahend: str
        Column storing data about the subtrahend.
        
    quandl_key: path
        Path to an excel-file, which stores the quandl-key in the first cell.
    
    Returns
    -------
    This functions returns the downloaded and pre-processed data as a dataframe. 
    """
    
    ## retrieve data
    df_stock_data = retrieve_stock_data(df_input=df_input_stocks, 
                                        date_start=date_start, 
                                        date_end=date_end, 
                                        wrds_username=wrds_username)
    
    # change type of entries in the columns date
    df_link['date']  = pd.to_datetime(df_link['date'])
    
    ## merge with cusip
    df_stock_data = pd.merge(df_stock_data, df_link.loc[:,['permno', 'date', 'secid']], how = "left", on = ['permno','date'])
    
    
    # Download Fama-French Factors
    df_ffm = download_ffm(date_start=date_start, date_end=date_end)
    
    ## merge stock data with ffm
    # merge with ff-4-factors
    df_stocks_factors = pd.merge(df_stock_data, df_ffm, how='inner', on=['date'])
    
    # calculate excess return
    df_stocks_factors  = calc_excess_return(df=df_stocks_factors, minuend=minuend, subtrahend=subtrahend)
    
    # get quandl data
    df_crude, df_yields, df_gold = get_quandl_data(quandl_key=quandl_key)
    ## merge with stock data
    df_stocks_factors = pd.merge(df_stocks_factors, df_crude, how='left', on=['date'])
    df_stocks_factors = pd.merge(df_stocks_factors, df_yields, how='left', on=['date'])
    df_stocks_factors = pd.merge(df_stocks_factors, df_gold, how='left', on=['date'])
    
    return df_stocks_factors

# %% [markdown]
# In the next cell, we call the function `data_prep` to download, pre-process and merge the data.

# %%
df_prepared = data_prep(df_input=df_input_stocks,
                        date_start='1999-01-01',
                        date_end='2019-12-31',
                        df_link=df_link_permno_secid,
                        wrds_username='sebastiansydow',
                        # wrds_username = 'strahinja23',
                        minuend='ret',
                        subtrahend='rf', 
                        quandl_key=quandl_key)
# Out:
# Loading library list...
# Done

# %% [markdown]
# # Estimation of $\beta$-Factors

# %%
def estimate_betas(df, window_size, factors, period='daily'):
    """
    This function calls the previously estimates the beta-factors for those characteristics, 
    which are not directly observable for each stock.

    Parameters
    ----------
    df_input: dataframe
        The dataframe storing the information about the stocks.
        
    windo_size: int
        The window for whcich the betas shall be estimated.
        
    factors: list
        List of factors, for which betas need to be estimated.
        
    period: str
        The period of recalculating the betas, (daily or monthly).
    
    Returns
    -------
    This functions returns dataframe with etimated betas, which are unique for each stock.
    """
    # identify all companies (permnos) in the dataframe
    permnos = df.permno.unique()
    # loop over all permnos and perform ols regression
    for permno in tqdm(range(len(permnos))):
        # define dataframe only with current permno
        df_current_permno = df[df['permno'] == permnos[permno]]
        # only perform OLS for stocks with more than 252 observations
        if len(df_current_permno) > window_size:
            # dependent variable
            Y = df_current_permno['excess_return']
            # independent variable
            X = df_current_permno[factors]
            # define constant
            X_constant = sm.add_constant(X)
            # define model
            rol_ols_model = RollingOLS(endog=Y, exog=X_constant, window=window_size)
            # fitting
            # print('Fitting rolling OLS model for permno #', permno, ' from', len(permnos))
            results = rol_ols_model.fit()
            # parameters
            if permno == 0:
                df_params = results.params
            else:
                df_params = pd.concat([df_params, results.params])

    # rename columns
    for col in factors:
        df_params.rename(columns={col: col+str('_beta')}, inplace=True)
    # df_params.rename(columns = {'mktrf':'beta1', 'smb':'beta2', 'hml':'beta3', 'mom': 'beta4'}, inplace = True)
    # merge with df_all by index
    print('Merging the dataframes...')
    df_betas = pd.merge(df, df_params, how='left', left_index=True, right_index=True, suffixes=[None, None])
    print('Merging completed.')
    
    if period == 'daily':
        df_betas.dropna(inplace=True)
        df_betas = df_betas.reset_index(drop=True)
        return df_betas
    
    if period == 'monthly':
        # add '_factor' to the entries in list factors
        ls_factors_betas = [factors[i] + str('_beta') for i in list(range(len(factors)))]
        # create a temporary copy of df_betas
        cols2copy=['permno', 'date', 'const']+ls_factors_betas
        df_temp = df_betas[cols2copy].copy()
        #df_temp = df_betas[['permno', 'date', 'const', 'beta1', 'beta2', 'beta3', 'beta4']].copy()

        # add necessary columns for group by
        df_temp['year'] = df_temp['date'].dt.year
        df_temp['month'] = df_temp['date'].dt.month
        # group dataframe and select last row 
        df_temp = df_temp.groupby(['permno','year', 'month']).tail(n=1)
        
        # rename columns to indicate that those are the betas of the end of each month
        for col in cols2copy[2:]:
            df_temp.rename(columns={col: col+str('_eom')}, inplace=True)
        # df_temp.rename(columns = {'const':'const_eom', 'beta1':'beta1_eom', 'beta2':'beta2_eom', 'beta3':'beta3_eom', 'beta4':'beta4_eom'}, inplace = True)
        # merge with df_betas
        df_betas_monthly = pd.merge(df_betas, df_temp, how='left', on=['date', 'permno'])
        # forward fill estimaed beta factors to assume that they stay constant for the next month until the last day
        gb = df_betas_monthly.groupby('permno')
        cols_eom = cols2copy[2:]
        cols_eom = [cols_eom[i] + str('_eom') for i in list(range(len(cols_eom)))]
        for var in cols_eom:
            df_betas_monthly[var] = gb[var].ffill()
        
        # drop daily betas
        #df_betas_monthly.drop(columns = {'const', 'beta1', 'beta2', 'beta3', 'beta4', 'year', 'month'}, inplace = True)
        df_betas_monthly.drop(['const', 'year', 'month'] + ls_factors_betas + factors, axis = 1, inplace=True)
        # drop nas
        df_betas_monthly.dropna(inplace=True)

        # reset index of df
        df_betas_monthly = df_betas_monthly.reset_index(drop=True)
        
        return df_betas_monthly

# %%
factors = ['mktrf', 'smb', 'hml', 'mom', 'ret_crude_oil', 'yield_dif_10y_1y', 'ret_gold']

df_betas = estimate_betas(df=df_prepared, window_size=252, factors=factors, period='monthly')
# Out:
# 100%|██████████| 50/50 [02:26<00:00,  2.93s/it]
# Merging the dataframes...
# Merging completed.

# %% [markdown]
# # Plotting of Return

# %%
# define a function to calculate the valued weighted average
def weighted_avg(df, values, weights):
    d = df[values]
    w = df[weights]
    return (d * w).sum() / w.sum()

# %%
def plot_benchmark_performance(df, column_ret, column_weight):
    # calculate benchmark performance on each day
    df_plot = (df.groupby(['date']).apply(weighted_avg, column_ret, column_weight)+1)
    df_plot.iloc[0] = df_plot.iloc[0] * 100
    
    # size of the plot
    fig, ax = plt.subplots(1, 1, figsize=(8,8))

    # define the spacing on the x-axis
    ## major ticks every 4 years
    major_ticks_years = mdates.YearLocator(4)  
    Axis.set_major_locator(ax.xaxis, major_ticks_years) 
    ## Minor ticks every year 
    minor_ticks_year = mdates.YearLocator(1)
    Axis.set_minor_locator(ax.xaxis, minor_ticks_year)

    # title
    plt.title(r"Value-Weighted Excess-Return of the Benchmark-Portfolio")

    # format the date type to year on the x-axis
    ax.format_xdata = mdates.DateFormatter('% m')

    # 9/11
    ax.annotate('9/11', xy=('2001-09-11 00:00:00', 120), xytext=(15, 15), 
                textcoords='offset points', arrowprops=dict(arrowstyle='-|>'))
    ax.axvline(x=pd.to_datetime('2001-09-11'), color='r', linestyle='--', lw=1)

    # bankruptcy Lehman 
    ax.annotate('Bankruptcy Lehman Brothers', xy=('2008-09-15 00:00:00', 90), xytext=(15, 15), 
                textcoords='offset points', arrowprops=dict(arrowstyle='-|>'))
    ax.axvline(x=pd.to_datetime('2008-09-15'), color='r', linestyle='--', lw=1)

    # covid
    ax.annotate('Covid-19', xy=('2020-03-16 00:00:00', 350), xytext=(-60, 5), 
                textcoords='offset points', arrowprops=dict(arrowstyle='-|>'))
    ax.axvline(x=pd.to_datetime('2020-03-16'), color='r', linestyle='--', lw=1)

    # define start and end of x-axis
    ax.set_xlim(min(df['date']), max(df['date']))

    # define labels of x- and y-axis
    ax.set(xlabel="Date",
           ylabel="Performance in % (Value-Weighted Mean of Benchmark Portfolio)")

    ax.plot(df_plot.cumprod(), label="Excess Return Benchmark")
    ax.legend(loc="upper left")
    # df_plot.cumprod().plot(figsize=(10,10))
    
    # quant_stats
    # qs.reports.html(df_plot.cumprod())

# %%
plot_benchmark_performance(df=df_betas, column_ret='ret', column_weight='weightage_pct')

# %% [markdown]
# # Option-Implied Data and Option Metrics
# ## GLB and MFIS
#
# In the next cell, the data for the generalized lower bounds for the expected excess simple returns (`df_glb`) and  risk-neutral skewness (`df_mfis`) are added.

# %%
# merge data with glb
df_stocks_betas_options = pd.merge(df_betas, df_glb, how="left", on=['permno', 'date'])
# merge data with mfis
df_stocks_betas_options = pd.merge(df_stocks_betas_options, df_mfis, how='left', on=['permno', 'date'])

# %% [markdown]
# ### Average Volatility [AIV] of all OTM Call and Put Options and SKEW

# %%
def retrieve_option_metrics(df, 
                            start_year, 
                            end_year, 
                            days, 
                            delta_otm_put, 
                            delta_atm_call, 
                            delta_otm_put2, 
                            delta_atm_call2, 
                            wrds_username):
    
    """
    This function retrieves the option metrics from WRDS.
    
    Parameters
    ----------
    df: dataframe
        The dataframe storing the information about the stocks.
        
    start_year: int
        First year of data retrieval.
        
    end_year: int
        Last year of data retrieval.
        
    days: int
        Number of days used for calulating the metrics.
    
    delta_otm_put: int
        Used for calculating skew, OTM put (delta)
    
    delta_atm_call: int
        Used for calculating skew, ATM put (delta)
    
    delta_otm_put2: int 
        Used for calculating skew2, OTM put (delta)
    
    delta_atm_call2: int
        Used for calculating skew2, ATM put (delta)
    
    wrds_username: str
        Username of the wrds-account used for the data retrieval.
        
    Returns
    -------
    This functions returns the downloaded option metrics as a dataframe. 
    """
    
    ## establish WRDS connection
    db = wrds.Connection(wrds_username=wrds_username)
    
    # define the parameters
    params = {}
    params['secids'] = tuple(df.secid.unique())
    params['days'] = days
    params['delta_otm_put'] = delta_otm_put
    params['delta_atm_call'] = delta_atm_call
    params['delta_otm_put2'] = delta_otm_put2
    params['delta_atm_call2'] = delta_atm_call2

    # define the sql query
    sql = '''
    select a.date, a.secid, a.iv-b.iv as skew1, c.iv, (g.iv-v.iv)/a.iv as skew2 from 

    (select date, secid, impl_volatility as iv 
    from optionm.vsurfd%(year)s
    where secid in %(secids)s and days = %(days)s and delta=%(delta_atm_call)s) as a, 

    (select date, secid, impl_volatility as iv 
    from optionm.vsurfd%(year)s
    where secid in %(secids)s and days = %(days)s and delta=%(delta_otm_put)s) as b, 

    (select date, secid, AVG(impl_volatility) as iv 
    from optionm.vsurfd%(year)s
    where secid in %(secids)s and days = %(days)s and abs(delta)<=%(delta_atm_call)s
    group by date, secid) as c,
    
    (select date, secid, impl_volatility as iv 
    from optionm.vsurfd%(year)s
    where secid in %(secids)s and days = %(days)s and delta=%(delta_otm_put2)s) as g, 

    (select date, secid, impl_volatility as iv 
    from optionm.vsurfd%(year)s
    where secid in %(secids)s and days = %(days)s and delta=%(delta_atm_call2)s) as v

    where a.date= b.date and a.secid = b.secid 
    and a.date = c.date and a.secid = c.secid
    and a.date = g.date and a.secid = g.secid
    and a.date = v.date and a.secid = v.secid
    '''
    # retrieve data for 1999
    params['year'] = start_year
    df_optiondata = db.raw_sql(sql, params = params)

    # append data for each year from 2000 to 2020
    for y in tqdm(range(start_year+1,end_year)):
        #print('Processing year ', y)
        # set parameter for the year
        params['year'] = y
        df_optiondata = pd.concat([df_optiondata, db.raw_sql(sql, params = params)])
        
    return df_optiondata

# %%
df_option_metrics = retrieve_option_metrics(df=df_stocks_betas_options,
                                            start_year=1999,
                                            end_year=2020,
                                            days=30,
                                            delta_otm_put=-10,
                                            delta_atm_call=50,
                                            delta_otm_put2=-25,
                                            delta_atm_call2=25,
                                            # wrds_username="strahinja23"
                                           wrds_username="sebastiansydow")

# change type of entries in the column data
df_option_metrics.loc[:,'date'] = pd.to_datetime(df_option_metrics.loc[:,'date'])

# merge optiondata and stockdata
df_stocks_betas_options = pd.merge(df_stocks_betas_options, df_option_metrics, how='left', on=['secid', 'date'])
# Out:
# Loading library list...
# Done
# 100%|██████████| 20/20 [00:47<00:00,  2.39s/it]

# %% [markdown]
# ## Technical Indicators

# %%
def technicals_rock(df_a):
    
    KAMA = KAMAIndicator(close = df_a["prc"],window = 10,pow1 = 2, pow2 = 30)
    PPO = PercentagePriceOscillator(close = df_a["prc"],window_slow = 26, window_fast = 12, window_sign = 9)
    ROCI = ROCIndicator(close=df_a["prc"],window=12)
    RSI = RSIIndicator(close=df_a["prc"],window = 14)
    EMA14 = EMAIndicator(close = df_a["prc"],window = 14)
    EMA25 = EMAIndicator(close = df_a["prc"],window = 25)
    MACD_ind = MACD(close = df_a["prc"],window_slow = 26,window_fast = 12,window_sign=9)
    Aroon = AroonIndicator(close = df_a["prc"],window = 25)
    
    df_a = df_a.assign(    
    KAMA = KAMA.kama(),
    PPO = PPO.ppo_signal(),
    ROCI = ROCI.roc(),
    RSI = RSI.rsi(),
    EMA14 = EMA14.ema_indicator(),
    EMA25 = EMA25.ema_indicator(),
    MACD = MACD_ind.macd_signal(),
    AroonInd = Aroon.aroon_indicator()
    )
    
    return df_a

# %%
df_stocks_betas_options = technicals_rock(df_stocks_betas_options)

# %% [markdown]
# ## Variance Risk Premium , please rewrite !

# %%
# db = wrds.Connection(wrds_username='strahinja23')
db = wrds.Connection(wrds_username='sebastiansydow')

sql = '''
select a.date,a.secid,a.return
from optionm.secprd%(year)s as a
where secid in %(secids)s
'''
params = {}
params['secids'] = tuple(df_stocks_betas_options.secid.unique())
params['year'] = 1999
options_returns = db.raw_sql(sql,params = params)

for y in range(2000,2020):
    print('Processing year ', y)
    params['year'] = y
    options_returns = pd.concat([options_returns, db.raw_sql(sql,params = params)])
    
options_returns.loc[:,'date'] = pd.to_datetime(options_returns.loc[:,'date'])
options_returns = options_returns.rename(columns={"return": "option_returns"})
options_returns = options_returns.set_index('date')

temp1 = options_returns.groupby(by=['secid'])['option_returns'].rolling(window=21).var()*252
temp1.name = 'realized_variance'
temp1 = temp1.reset_index()

df_stocks_betas_options = df_stocks_betas_options.merge(temp1,how='left',on=['date','secid'])
df_stocks_betas_options.loc[:,'vrp'] = (df_stocks_betas_options.loc[:,'iv']**2).rolling(21).sum()/(df_stocks_betas_options.loc[:,'realized_variance']).rolling(21).sum()
df_stocks_betas_options.drop(['realized_variance'], inplace=True, axis=1)
# Out:
# Loading library list...
# Done
# Processing year  2000
# Processing year  2001
# Processing year  2002
# Processing year  2003
# Processing year  2004
# Processing year  2005
# Processing year  2006
# Processing year  2007
# Processing year  2008
# Processing year  2009
# Processing year  2010
# Processing year  2011
# Processing year  2012
# Processing year  2013
# Processing year  2014
# Processing year  2015
# Processing year  2016
# Processing year  2017
# Processing year  2018
# Processing year  2019

# %%
df_stocks_betas_options.to_hdf(hdf_path, key = 'factors', mode= 'a',data_columns = True, complib = 'zlib')
df_stocks_betas_options = pd.read_hdf(hdf_path,key='factors')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Delete Columns with many NaNs

# %%
def count_nan(df):
    """
    This function counts None values on each column plots the count as a bar-chart.

    Parameters
    ----------
    df_input: dataframe
        The dataframe with the columns for which the count of None values shall be plotted.
    
    Returns
    -------
    This functions returns the plotted None values as a bar-chart.
    """
    # Count NaN
    df_count_nan = df.isna().sum().reset_index(name="Count NaN")
    # Rename column
    df_count_nan = df_count_nan.rename(columns={"index": "Column"})
    # Plot
    df_count_nan.plot.bar(x='Column', 
                          y='Count NaN', 
                          rot=45, 
                          figsize=(16,6), 
                          title="Count NaN per Column")

# %%
count_nan(df=df_stocks_betas_options)

# %%
# drop columns with many nas
df_stocks_betas_options.drop(['glb2_D182', 
                              'glb3_D182', 
                              'glb2_D273', 
                              'glb3_D273', 
                              'glb2_D365', 
                              'glb3_D365',
                              'mfis182',
                              'mfis273', 
                              'mfis365'], inplace=True, axis=1)

# %% [markdown]
# ## Multicollinearity
# Multicollinearity occurs when there are two or more independent variables in a multiple regression model, which have a high correlation among themselves (see also [here](https://www.geeksforgeeks.org/detecting-multicollinearity-with-vif-python/) and [here](https://www.investopedia.com/terms/m/multicollinearity.asp)). This may lead to difficulties, when trying to distinguis between their individual effects on the dependent variable. <br>
# In statistics, one commone approach to quantify a relationship between two variables is to the [Pearson correlation coefficient](https://www.statology.org/pearson-correlation-coefficient/), which is a measure of the linear association between two variables. It has a value between -1 and 1 where:
# - -1 indicates a perfectly negative linear correlation between two variables
# - 0 indicates no linear correlation between two variables
# - 1 indicates a perfectly positive linear correlation between two variables
#
# The further away the Pearson correlation coefficient is away from zero, the stronger the relationship between the two variables.
# The pairwise Pearson correlation coefficient of the respective variables can be clearly visualized using the correlation matrix as a heatmap.

# %%
def corrmatrix_heatmap(df, columns):
    """
    This function calculates the pairwise Pearson correlation coefficient of the respective variables
    and plots them in a heatmap.
    
    Parameters
    ----------
    df: dataframe
        The dataframe storing the information about the stocks.
        
    columns: list
        The variables for which the Pearson correlation coefficient shall be calculated.
        
    Returns
    -------
    This functions returns the heatmap of the pairwise Pearson correlation coefficient. 
    """
    
    X = df[columns]

    # Compute the correlation matrix
    corrMatrix = X.corr()

    # Set up the matplotlib figure
    f, ax = plt.subplots(figsize=(14, 11))

    sns.heatmap(corrMatrix, annot=True)
    # plt.savefig('corrMatrix_heatmap.jpeg', dpi=200, format='jpeg')

# %%
# define columns to calculate pearson correlation coefficient for
idx = list(df_stocks_betas_options.columns).index("excess_return")
columns = list(df_stocks_betas_options.columns)[idx+1:]

# execute function
corrmatrix_heatmap(df=df_stocks_betas_options, columns=columns)

# %% [markdown]
# In the next cells, we use the [variance inflation factor (VIF)](https://www.statsmodels.org/devel/generated/statsmodels.stats.outliers_influence.variance_inflation_factor.html) to additionally measure the amount of collinearity. One recommendation is that if VIF is greater than 5, then the explanatory variable given by exog_idx is highly collinear with the other explanatory variables, and the parameter estimates will have large standard errors because of this.

# %%
def VIF_Features(df):
    """
    This function calculates the variance inflation factor (VIF).
    
    Parameters
    ----------
    df: dataframe
        The dataframe storing the information about the stocks.
        
    Returns
    -------
    This functions returns variance inflation factors. 
    """
    
    X_ = df.copy()
    X_ = X_[X_.columns[10:]]
    X_ = X_.dropna()
    
    vif_data = pd.DataFrame()
    vif_data["feature"] = X_.columns
    vif_data["VIF"] = [variance_inflation_factor(X_.values, i) for i in range(len(X_.columns))]
    
    return vif_data

# %%
# drop columns
df_stocks_betas_options.drop(['glb2_D30', 
                              #'glb3_D30', 
                              'glb2_D91', 
                              'glb3_D91',
                              'mfis30',
                             'EMA25',
                              'EMA14',
                              'KAMA'
                             ], inplace=True, axis=1)

# %%
dd = VIF_Features(df_stocks_betas_options)
dd
# Out:
#                       feature        VIF
# 0              mktrf_beta_eom   9.268341
# 1                smb_beta_eom   1.907073
# 2                hml_beta_eom   1.060844
# 3                mom_beta_eom   1.143129
# 4      ret_crude_oil_beta_eom   1.077334
# 5   yield_dif_10y_1y_beta_eom   1.010998
# 6           ret_gold_beta_eom   1.079474
# 7                    glb3_D30   4.111634
# 8                      mfis91   5.930978
# 9                       skew1   2.715256
# 10                         iv  14.238881
# 11                      skew2   1.382461
# 12                        PPO  12.046599
# 13                       ROCI   1.200353
# 14                        RSI  23.813529
# 15                       MACD  11.754814
# 16                   AroonInd   1.683632
# 17                        vrp   9.656956

# %% [markdown]
# ## Returns, Train, Test Split and Normalization

# %%
def alpha_returns(df,kind):
    if kind == 'Alpha':
        benchmark_returns = df.groupby(['date'])[['weightage_pct','ret']].apply(lambda x: np.nansum(x['ret']*x['weightage_pct']))
        benchmark_returns.name = 'ret_benchmark'                     
        df = df.merge(benchmark_returns, on=['date'])
        df['ret_bm_fw'] = df.groupby(['permno'])['ret_benchmark'].shift(-1)
        df.loc[:,'fret1d'] = df.groupby(['permno'])['ret'].shift(-1)
        df['fret1d'] = df['fret1d'] - df['ret_bm_fw']
        df.drop(columns = {'ret_bm_fw', 'ret_benchmark'}, inplace = True)
    if kind == 'Regular':
        df.loc[:,'fret1d'] = df.groupby(['permno'])['ret'].shift(-1)
    
    return df

# %%
df_stocks_betas_options = alpha_returns(df_stocks_betas_options,kind = 'Regular')

# %%
def train_test_split_sorted(df,date_of_split, dates):   
    
    date_of_split = pd.to_datetime(date_of_split)
    X_train = df[(df["date"] <= date_of_split) & (df['date'] > pd.datetime(1999, 12, 31))]
    X_test = df[(df["date"] > date_of_split) & (df['date'] < pd.datetime(2020, 1, 1))]
    
    X_train = X_train.sort_values(by=['date','permno'])
    X_test = X_test.sort_values(by=['date','permno'])

    return X_train,X_test

# %%
df_stocks_betas_options.loc[:,'date'] = pd.to_datetime(df_stocks_betas_options.loc[:,'date'])


train,test = train_test_split_sorted(df=df_stocks_betas_options,
                                     date_of_split=pd.datetime(2012, 12, 31),
                                     dates=df_stocks_betas_options.date)

# %%
def process(df,columns):
    df_scaled = df.copy()

    df_scaled = df_scaled.fillna(method='ffill',limit=30,inplace=False)
    df_scaled = df_scaled.dropna()
    
    for column in columns:
       
    # df_scaled[column] = (df_scaled[column] - df_scaled[column].mean())  / df_scaled[column].std()
        df_scaled[column] = (df_scaled[column] - df_scaled[column].min())  / (df_scaled[column].max() - df_scaled[column].min())
        df_scaled[column], fitted_lambda = stats.boxcox(df_scaled[column] + 0.0001) 
        df_scaled.loc[:,column] = winsorize(df_scaled.loc[:,column], limits=0.01).data
        df_scaled[column] -= df_scaled[column].mean()
                                                                     
    
    return df_scaled

# %%
columns2norm = train.columns[10:-1]

# Only the train gets processed, the rest will be processed on a rolling window in the testing phase
train = process(train, columns2norm)

# %%
cols = ['skew1', 'skew2', 'iv','RSI','mktrf_beta_eom','smb_beta_eom','mom_beta_eom','hml_beta_eom','yield_dif_10y_1y_beta_eom' ]#,'vrp', 'AroonInd']
fig, axs = plt.subplots(3,3)
fig.set_size_inches(18.5, 12.5, forward=True)
fig.suptitle('Distribution of Variables', fontsize=18)

for i,el in enumerate(cols):
    a = train.hist(el, ax=axs.flatten()[i],bins=100)

# %% [markdown]
# ## Modelling the Prediction of Returns

# %%
def Rolling_Forest(data,predictors,target,window,params):

# First we form the window 
    start_window = data.date.min()
    end_window = data.date.min() + BDay(window)
    pred_date = end_window + BDay(1)

#Auxiliary placeholders and reg. constant
    data = data.sort_values(by=['date','permno'])
    predictions_df = pd.DataFrame(index=[pred_date], columns=np.sort(data.permno.unique()))
    scores = []
    missing_dates = []

# The train / predict loop
    while pred_date <= data.date.max():
# The loop will go through business days, not necessarily trading days (hence the try clause).        
        try:
        # Picking the window of data to train and instantiating the predictor model
            mask = ((data['date'] >= start_window) & (data['date'] <= end_window))
            train_window = data[mask].set_index('permno')
            linreg = RandomForestRegressor(**params)
        # Fitting the model on the training window     
            fit_ = linreg.fit(train_window[list(predictors)],train_window[target])
        # Predicting for each permno on the next day after fit    
            predi_df = data[data['date']== pred_date].loc[:,list(predictors)+['permno']].set_index('permno')
            predi = fit_.predict(predi_df)
        # Storing in a useful format for backtest
            one_predi = (pd.DataFrame(data = predi, index=predi_df.index,columns=[pred_date])).T
            predictions_df = pd.concat([predictions_df,one_predi], axis=0, ignore_index=False)
       # R^2 to help visualize training performance     
            score_r2 = linreg.score(predi_df[list(predictors)], data[data['date']== pred_date][target])
            scores.append(score_r2)
        except:
            missing_dates.append(pred_date)
# Update window position        
        start_window = start_window + BDay(1)
        end_window = start_window + BDay(window)
        pred_date = end_window + BDay(1)
# Real returns we will need

    # real_returns = data.pivot_table(index='date', columns='permno', values='fret1d')
    real_returns = data.pivot(index='date', columns='permno', values='fret1d')
   # r2_average = np.mean(scores)
    
    return real_returns, predictions_df[1:], missing_dates,scores #, r2_average
    # return data

# %%
def timer(start_time=None):
    if not start_time:
        start_time = datetime.datetime.now()
        return start_time
    elif start_time:
        thour, temp_sec = divmod((datetime.datetime.now() - start_time).total_seconds(), 3600)
        tmin, tsec = divmod(temp_sec, 60)
        print('\n Time taken: %i hours %i minutes and %s seconds.' % (thour, tmin, round(tsec, 2)))

# %%
params = {
        'n_estimators': [10, 20, 30],
        'max_features': ['sqrt','auto','log2'],
        'max_depth': [3, 4, 5],
        'min_samples_leaf':[1,2,3,4],
        'min_samples_split':[2,3,4,5]
        }

train.insert(10, 'constant', 1.0)
regressors = train.columns[10:-1]
target = ['fret1d']


forest = RandomForestRegressor()

folds = 3
param_comb = 5

random_search = RandomizedSearchCV(forest, param_distributions=params, n_iter=param_comb, scoring='r2', 
                                   n_jobs=4, cv=KFold(5), verbose=3, random_state=1001 )
                                                #KFold is not shuffled !

# Here we go 
start_time = timer(None) # timing starts from this point for "start_time" variable
random_search.fit(train[regressors], train[target])
timer(start_time) # timing ends here for "start_time" variable
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  25 out of  25 | elapsed:  1.5min finished
#  Time taken: 0 hours 1 minutes and 38.94 seconds.

# %%
print('\n Best estimator:')
print(random_search.best_estimator_)
print('\n Best normalized gini score for %d-fold search with %d parameter combinations:' % (folds, param_comb))
print(random_search.best_score_ * 2 - 1)
print('\n Best hyperparameters:')
print(random_search.best_params_)
# Out:
#  Best estimator:
# RandomForestRegressor(max_depth=5, max_features='sqrt', min_samples_leaf=3,
#                       min_samples_split=4, n_estimators=30)
#
#  Best normalized gini score for 3-fold search with 5 parameter combinations:
# -1.00019817215048
#
#  Best hyperparameters:
# {'n_estimators': 30, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': 5}

# %%
params_forest = {
    "n_estimators": 30,
    'max_features':'sqrt', 
    'max_depth':5,
    'min_samples_leaf':3,
    'min_samples_split':4,
    'random_state':1001,
    }

#train.insert(10, 'constant', 1.0) MAKE SURE TO RUN IF NOT ALREADY INSERTED IN GRIDSEARCH !
regressors = train.columns[10:-1]
target = ['fret1d']

real_returns_forest, expected_returns_forest, missing_dates_forest, scores_forest = Rolling_Forest(data=train, 
                                                              predictors=regressors,
                                                              target=target, 
                                                              window=126,
                                                              params=params_forest)

# %%
np.min(scores_forest)
# Out:
# -5.7797987765635

# %% [markdown]
# ## Lasso

# %% [markdown]
# We will tune the alpha on the whole train set and then again apply a rolling approach to predict

# %%
def lasso_regression(data, predictors, target, alpha):
    
    lasso = Lasso(alpha=alpha,normalize=True, max_iter=1e5).fit(data[predictors],data[target])
    predi = lasso.predict(data[predictors]) 
    score=lasso.score(data[predictors],data[target])
    n = np.sum(lasso.coef_!=0)
    mse=metrics.mean_squared_error(data[target].to_numpy(), predi)
    
    return mse, score,n

# %%
regressors
# Out:
# Index(['constant', 'mktrf_beta_eom', 'smb_beta_eom', 'hml_beta_eom',
#        'mom_beta_eom', 'ret_crude_oil_beta_eom', 'yield_dif_10y_1y_beta_eom',
#        'ret_gold_beta_eom', 'glb3_D30', 'mfis91', 'skew1', 'iv', 'skew2',
#        'PPO', 'ROCI', 'RSI', 'MACD', 'AroonInd', 'vrp'],
#       dtype='object')

# %%
alpha_lasso = [1e-16,1e-8, 1e-4, 1e-2, 1, 10]
res = pd.DataFrame(index =alpha_lasso, columns=['MSE'])
for i in range(len(alpha_lasso)):
    res.loc[alpha_lasso[i],'MSE'],  res.loc[alpha_lasso[i],'Score'],\
    res.loc[alpha_lasso[i],'No.'] = lasso_regression(train,regressors,target, alpha_lasso[i])

# %%
def Rolling_Lasso(data,predictors,target,window,alpha):

# First we form the window 
    start_window = data.date.min()
    end_window = data.date.min() + BDay(window)
    pred_date = end_window + BDay(1)

#Auxiliary placeholders and reg. constant
    data = data.sort_values(by=['date','permno'])
    predictions_df = pd.DataFrame(index=[pred_date], columns=np.sort(data.permno.unique()))
    scores = []
    missing_dates = []

# The train / predict loop
    while pred_date <= data.date.max():
# The loop will go through business days, not necessarily trading days (hence the try clause).        
        try:
        # Picking the window of data to train and instantiating the predictor model
            mask = ((data['date'] >= start_window) & (data['date'] <= end_window))
            train_window = data[mask].set_index('permno')
            linreg = Lasso(alpha=alpha,normalize=True, max_iter=1e5)
        # Fitting the model on the training window     
            fit_ = linreg.fit(train_window[list(predictors)],train_window[target])
        # Predicting for each permno on the next day after fit    
            predi_df = data[data['date']== pred_date].loc[:,list(predictors)+['permno']].set_index('permno')
            predi = fit_.predict(predi_df)
        # Storing in a useful format for backtest
            one_predi = (pd.DataFrame(data = predi, index=predi_df.index,columns=[pred_date])).T
            predictions_df = pd.concat([predictions_df,one_predi], axis=0, ignore_index=False)
       # R^2 to help visualize training performance     
            score_r2 = linreg.score(predi_df[list(predictors)], data[data['date']== pred_date][target])
            scores.append(score_r2)
        except:
            missing_dates.append(pred_date)
# Update window position        
        start_window = start_window + BDay(1)
        end_window = start_window + BDay(window)
        pred_date = end_window + BDay(1)
# Real returns we will need

    # real_returns = data.pivot_table(index='date', columns='permno', values='fret1d')
    real_returns = data.pivot(index='date', columns='permno', values='fret1d')
   # r2_average = np.mean(scores)
    
    return real_returns, predictions_df[1:], missing_dates,scores #, r2_average
    # return data

# %%
real_returns_lasso, expected_returns_lasso, missing_dates_lasso, scores_lasso = Rolling_Lasso(data=train, 
                                                              predictors=regressors,
                                                              target=target, 
                                                              window=126,
                                                              alpha=1e-8)

# %%
np.mean(scores_lasso)
# Out:
# -0.3603786731758346

# %%
expected_returns_forest.to_hdf(hdf_path, key = 'Predictions', mode= 'a',data_columns = True, complib = 'zlib')
real_returns_forest.to_hdf(hdf_path, key = 'Real', mode= 'a',data_columns = True, complib = 'zlib')

# %%
real_returns = pd.read_hdf(hdf_path,key='Real')
expected_returns = pd.read_hdf(hdf_path,key='Predictions')

# %% [markdown]
# ## Backtest

# %%
def prepare_returns(real, expected, days_to_test,years_lookback):


    real = real.loc[np.logical_and(real.index >= days_to_test - pd.Timedelta(days=252*years_lookback + 1), real.index < days_to_test), :]
    expected = expected.loc[np.logical_and(expected.index >= days_to_test - pd.Timedelta(days=252*years_lookback + 1), expected.index < days_to_test), :]   
    
    real = real.fillna(0.0)
    expected = expected.fillna(0.0)
    
    return real, expected

# %%
real,ret = prepare_returns(real_returns,expected_returns,pd.datetime(2012, 12, 28),5)

# %%
def MSR(wvec,*args):
     cov = args[0]
     mu  = args[1]  # Max Sharp Ratio
     sr = mu@wvec/(wvec@cov@wvec)
     return -sr * 1e9

def MVP(wvec,*args):
     cov = args[0]
     var = wvec@cov@wvec
     return var

# %%
def Benchmark_Drawdown_Rolling(df,ret,d,lookback):
    
    d = pd.Timestamp(d)
    start = d - BDay(lookback)
    
    means = ret.loc[start:(d-BDay(1)),:].values
    means_df = ret.loc[start:(d-BDay(1)),:]

    weights_bench = df[(df['date']>= start) & (df['date'] < d)]
    weights_bench = weights_bench[['date','permno','weightage_pct']]
    weights_bench = weights_bench.pivot(index = 'date',columns = 'permno',values='weightage_pct')
    weights_bench = weights_bench.loc[weights_bench.index.isin(means_df.index)]
    
    monthly_benchmark_returns = (means*weights_bench).sum(axis=1)
    monthly_benchmark_returns = pd.DataFrame(monthly_benchmark_returns,columns=["Benchmark_Return"])
    # cumulative return
    monthly_benchmark_returns['Cum_ret'] = (1+ monthly_benchmark_returns['Benchmark_Return']).cumprod()
    # cumulative peaks
    monthly_benchmark_returns['Peaks'] = monthly_benchmark_returns['Cum_ret'].cummax()
    # drawdown from trailing peak
    monthly_benchmark_returns['Drawdown'] = (monthly_benchmark_returns['Cum_ret'] - monthly_benchmark_returns['Peaks']) / monthly_benchmark_returns['Peaks']
    
    return monthly_benchmark_returns, monthly_benchmark_returns['Drawdown'].min()

# %%
def configure_inputs_for_optimisation(df, ret, expret, d, limit,lookback):

    cov = ret.cov().values
    mu  = expret.iloc[-1].values
    mu = mu - np.mean(mu)
    mu = winsorize(mu, limits=0.1).data
 
    if np.sum(mu > 0) == 0:
        mu -= mu.mean()
    
 # ----- Bounds on Weights Based on Benchmark on day d  ---- #
    bounds = [ [] for _ in range(len(ret.columns)) ] # Empty placeholder for the 50 lower and upper bounds per day
    for en,i in enumerate(ret.columns, start=0): # 
        try:
            lower_bound = 0.9*float(df.loc[df['date']==d][df['permno']== i].weightage_pct.values)
            higher_bound = 1.1*float(df.loc[df['date']==d][df['permno']== i].weightage_pct.values)
            bounds[en].extend((lower_bound,higher_bound))
        except:
            lower_bound = 0.0
            higher_bound = 0.0
            bounds[en].extend((lower_bound,higher_bound))
              
 # ----- Constraints on Factor Exposure: ---- #
    cons = []
    fact = pd.DataFrame(columns=list(regressors)+['permno'] )
    fact.permno = ret.columns.tolist()
    fact.set_index('permno', inplace=True)
    fact = fact.fillna(0.0)

    #Exposure of strategy

    for stock in fact.index:
        for fct in fact.columns:
            flt = np.logical_and(df['date'] == d, df['permno'] == stock)
            if flt.any():
                fact.loc[stock, fct] = df.loc[flt, fct].values[0]
    
    
    B = fact.T[1:]
    
    # Benchmark Weights
    weights_Benchmark = df.loc[df['date']==d][['permno','weightage_pct']]
    weights_Benchmark = weights_Benchmark.sort_values('permno')
    weights_Benchmark = weights_Benchmark.set_index(['permno']).squeeze()
    for i in df.permno.unique():
        if i not in weights_Benchmark.index:
            weights_Benchmark[i] = 0.0
    weights_Benchmark = weights_Benchmark.sort_index()
    
    
    cons.append({'type': 'ineq', 'fun' : lambda wvec: B@weights_Benchmark- B@wvec + limit})
    cons.append({'type': 'ineq', 'fun' : lambda wvec: B@wvec -B@weights_Benchmark + limit}) 
 
 # ----- Constraints on Weight Sum (long portfolio): ---- #

    cons.append({'type': 'eq', 'fun' : lambda wvec: wvec.sum()-1})
    
#  # ----- Constraints on Drawdown: ---- #
    if (pd.Timestamp(d)- BDay(lookback)) in ret.index:
        _,benchmark_dd = Benchmark_Drawdown_Rolling(df,ret,d,21)
        cons.append({'type': 'ineq', 'fun' : lambda wvec: mu.T@wvec-(benchmark_dd-0.01)})        
    
    return cov, mu, cons, bounds

# %% [markdown]
# ## Sanity Check on Weight Bounds

# %%
dtall = pd.DataFrame(index = ret.index, data = ret.index, columns = ['dates']) #
dt_m = dtall.groupby(pd.Grouper(freq='B')).last() # We can rebalane daily for final solution should be better results
dates_rebal = dt_m.index.values                   # But less realistic (daily trading)

# %%
bounds = [ [] for _ in range(len(ret.columns)) ] # Empty placeholder for the 50 lower and upper bounds per day
d = dates_rebal[0]
for en,i in enumerate(ret.columns, start=0): # 

    lower_bound = 0.9*float(train.loc[train['date']==d][train['permno']== i].weightage_pct.values)
    higher_bound = 1.1*float(train.loc[train['date']==d][train['permno']== i].weightage_pct.values)
    bounds[en].extend((lower_bound,higher_bound))

# %%
bounds[11] # Alles gut !
# Out:
# [0.028529286662624064, 0.03486912814320719]

# %%
train.loc[train['date']==dates_rebal[0]][train['permno']== ret.columns[11]].weightage_pct.values
# Out:
# array([0.03169921])

# %% [markdown]
# ## Sanity Check on Factor Exposure

# %%
fact = pd.DataFrame(columns=list(regressors)+['permno'] )
fact.permno = ret.columns.tolist()
fact.set_index('permno', inplace=True)
fact = fact.fillna(0.0)

# %%
for stock in fact.index:
    for fct in fact.columns:
        flt = np.logical_and(train['date'] == dates_rebal[0], train['permno'] == stock)
        if flt.any():
            fact.loc[stock, fct] = train.loc[flt, fct].values[0]

# %%
#fact

# %% [markdown]
# ## Run the whole loop on Weekly rebalance

# %%
dtall = pd.DataFrame(index = ret.index, data = ret.index, columns = ['dates']) #
dt_m = dtall.groupby(pd.Grouper(freq='B')).last() # We can rebalane daily for final solution should be better results
dates_rebal = dt_m.index.values # But less realistic (daily trading)

 # We need to also exclude from rebalance dates the business days that were actually not trading days
# #missing_dates = [i.to_datetime64() for i in missing_dates] # Uncomment if needed a convert!
dates_rebal = [x for x in dates_rebal if x not in missing_dates_forest]

# %%
len(dates_rebal)
# Out:
# 870

# %%
names = ret.columns
ptf = {} 

# Initiate a dictionary of placeholders for the 3 strategies
ptf['msr_w_cons'] = pd.DataFrame(data = 0.0, index = dates_rebal, columns = names)
ptf['minvar_w_cons'] = pd.DataFrame(data = 0.0, index = dates_rebal, columns = names)

# %%
# Optimization rutine for the 2 minimization problems and for the closed form solution
st_point_msr = None
st_point_mvp = None

for d in dates_rebal: 
    print(d)    
    start_time = time.time()

    ret, expret = prepare_returns(real_returns,expected_returns,d,3)

    # we prepare inputs:
    cov,mu,cons,bounds = configure_inputs_for_optimisation(train, ret, expret, d, 0.05,21)

    # define starting point
    if st_point_msr is None:
        st_point_msr = np.ones(ret.columns.size)/ret.columns.size
    if st_point_mvp is None:
        st_point_mvp = np.ones(ret.columns.size)/ret.columns.size

    # run optimisation, MSR
    res = minimize(MSR,
                st_point_msr,
                args = (cov, mu), 
                constraints = cons, 
                bounds = bounds, 
                method = 'SLSQP',
                options={'ftol': 1e-16, 'disp': False})
    print("MSR: " + res.message)
    
    st_point_msr = res.x

    # store results
#     i = 0
#     for col in ret.columns:
#         ptf['msr_w_cons'].loc[d, col] = res.x[i]
#         i += 1
    ptf['msr_w_cons'].loc[d] = res.x
    
    res = minimize(MVP,
                st_point_mvp,
                args = (cov, mu), 
                constraints = cons, 
                bounds = bounds, 
                method = 'SLSQP',
                options={'ftol': 1e-16, 'disp': False})
    
    print("MVP: " + res.message)
    ptf['minvar_w_cons'].loc[d] = res.x

    # Set next starting point
    st_point_mvp = res.x

    
    print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 2009-07-16T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 16.53306794166565 seconds ---
# 2009-07-17T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.3776021003723145 seconds ---
# 2009-07-20T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.727482080459595 seconds ---
# 2009-07-21T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.309895992279053 seconds ---
# 2009-07-22T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.166568279266357 seconds ---
# 2009-07-23T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.12172794342041 seconds ---
# 2009-07-24T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.8446526527404785 seconds ---
# 2009-07-27T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.58570909500122 seconds ---
# 2009-07-28T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 10.774678945541382 seconds ---
# 2009-07-29T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.1831889152526855 seconds ---
# 2009-07-30T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.735567092895508 seconds ---
# 2009-07-31T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.335026979446411 seconds ---
# 2009-08-03T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.155079126358032 seconds ---
# 2009-08-04T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.765340089797974 seconds ---
# 2009-08-05T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 8.918300867080688 seconds ---
# 2009-08-06T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 7.5122129917144775 seconds ---
# 2009-08-07T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.405654668807983 seconds ---
# 2009-08-10T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.974677085876465 seconds ---
# 2009-08-11T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.2919340133667 seconds ---
# 2009-08-12T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.863724946975708 seconds ---
# 2009-08-13T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 7.05043625831604 seconds ---
# 2009-08-14T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.803134918212891 seconds ---
# 2009-08-17T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.3899829387664795 seconds ---
# 2009-08-18T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.400438070297241 seconds ---
# 2009-08-19T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.720090866088867 seconds ---
# 2009-08-20T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.298206806182861 seconds ---
# 2009-08-21T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.279396057128906 seconds ---
# 2009-08-24T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.782278299331665 seconds ---
# 2009-08-25T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.5164430141448975 seconds ---
# 2009-08-26T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.869762897491455 seconds ---
# 2009-08-27T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.923128128051758 seconds ---
# 2009-08-28T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.314690113067627 seconds ---
# 2009-08-31T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.736292839050293 seconds ---
# 2009-09-01T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.711586952209473 seconds ---
# 2009-09-02T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.415959119796753 seconds ---
# 2009-09-03T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.545886993408203 seconds ---
# 2009-09-04T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.3028647899627686 seconds ---
# 2009-09-08T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.391182899475098 seconds ---
# 2009-09-09T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.147162914276123 seconds ---
# 2009-09-10T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.489804983139038 seconds ---
# 2009-09-11T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.052578926086426 seconds ---
# 2009-09-14T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 3.967982053756714 seconds ---
# 2009-09-15T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 3.816962718963623 seconds ---
# 2009-09-16T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 3.64145827293396 seconds ---
# 2009-09-17T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.45766019821167 seconds ---
# 2009-09-18T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.401854038238525 seconds ---
# 2009-09-21T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.215014219284058 seconds ---
# 2009-09-22T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.0559728145599365 seconds ---
# 2009-09-23T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.008553981781006 seconds ---
# 2009-09-24T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.170317888259888 seconds ---
# 2009-09-25T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.606852054595947 seconds ---
# 2009-09-28T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 3.9070119857788086 seconds ---
# 2009-09-29T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.534604787826538 seconds ---
# 2009-09-30T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.129201173782349 seconds ---
# 2009-10-01T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.371727705001831 seconds ---
# 2009-10-02T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.230304002761841 seconds ---
# 2009-10-05T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.373797178268433 seconds ---
# 2009-10-06T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.787376880645752 seconds ---
# 2009-10-07T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.799016952514648 seconds ---
# 2009-10-08T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.7498931884765625 seconds ---
# 2009-10-09T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.134047985076904 seconds ---
# 2009-10-12T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.3923399448394775 seconds ---
# 2009-10-13T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.014498949050903 seconds ---
# 2009-10-14T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.046156167984009 seconds ---
# 2009-10-15T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.751260042190552 seconds ---
# 2009-10-16T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.261361122131348 seconds ---
# 2009-10-19T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 3.927574872970581 seconds ---
# 2009-10-20T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.116917848587036 seconds ---
# 2009-10-21T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.211341142654419 seconds ---
# 2009-10-22T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.152350187301636 seconds ---
# 2009-10-23T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.579500913619995 seconds ---
# 2009-10-26T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.387397050857544 seconds ---
# 2009-10-27T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 24.625443696975708 seconds ---
# 2009-10-28T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 12.591043949127197 seconds ---
# 2009-10-29T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 12.790201187133789 seconds ---
# 2009-10-30T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 16.07515287399292 seconds ---
# 2009-11-02T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 12.205717086791992 seconds ---
# 2009-11-03T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 10.74774980545044 seconds ---
# 2009-11-04T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 14.474950790405273 seconds ---
# 2009-11-05T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 12.650583982467651 seconds ---
# 2009-11-06T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 11.073994159698486 seconds ---
# 2009-11-09T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.486343860626221 seconds ---
# 2009-11-10T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.054155111312866 seconds ---
# 2009-11-11T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.273719787597656 seconds ---
# 2009-11-12T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.520365238189697 seconds ---
# 2009-11-13T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.556689977645874 seconds ---
# 2009-11-16T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 7.994356870651245 seconds ---
# 2009-11-17T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 16.289970874786377 seconds ---
# 2009-11-18T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 12.33216404914856 seconds ---
# 2009-11-19T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 9.223354816436768 seconds ---
# 2009-11-20T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 11.033686876296997 seconds ---
# 2009-11-23T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.956954717636108 seconds ---
# 2009-11-24T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 11.68017578125 seconds ---
# 2009-11-25T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 10.156817197799683 seconds ---
# 2009-11-27T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 7.867424964904785 seconds ---
# 2009-11-30T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.169140100479126 seconds ---
# 2009-12-01T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 11.575342655181885 seconds ---
# 2009-12-02T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 10.995684146881104 seconds ---
# 2009-12-03T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.762108087539673 seconds ---
# 2009-12-04T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 8.771867752075195 seconds ---
# 2009-12-07T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 33.871668100357056 seconds ---
# 2009-12-08T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 15.91330885887146 seconds ---
# 2009-12-09T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.908339023590088 seconds ---
# 2009-12-10T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.57220721244812 seconds ---
# 2009-12-11T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.875525712966919 seconds ---
# 2009-12-14T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.9271910190582275 seconds ---
# 2009-12-15T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.035175085067749 seconds ---
# 2009-12-16T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.539812803268433 seconds ---
# 2009-12-17T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.495163917541504 seconds ---
# 2009-12-18T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.483940839767456 seconds ---
# 2009-12-21T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.179017066955566 seconds ---
# 2009-12-22T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 10.829510927200317 seconds ---
# 2009-12-23T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 8.499520063400269 seconds ---
# 2009-12-24T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.266649961471558 seconds ---
# 2009-12-28T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 7.664569854736328 seconds ---
# 2009-12-29T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.505234956741333 seconds ---
# 2009-12-30T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.140311002731323 seconds ---
# 2009-12-31T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 7.614553928375244 seconds ---
# 2010-01-04T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.003798961639404 seconds ---
# 2010-01-05T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.5874717235565186 seconds ---
# 2010-01-06T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.823153972625732 seconds ---
# 2010-01-07T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.596649885177612 seconds ---
# 2010-01-08T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.706582069396973 seconds ---
# 2010-01-11T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.578984022140503 seconds ---
# 2010-01-12T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.890952110290527 seconds ---
# 2010-01-13T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.139416933059692 seconds ---
# 2010-01-14T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.952692985534668 seconds ---
# 2010-01-15T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.64467716217041 seconds ---
# 2010-01-19T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.809947729110718 seconds ---
# 2010-01-20T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.2683939933776855 seconds ---
# 2010-01-21T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.509461879730225 seconds ---
# 2010-01-22T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.808737993240356 seconds ---
# 2010-01-25T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 14.025595903396606 seconds ---
# 2010-01-26T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.811021089553833 seconds ---
# 2010-01-27T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.655285835266113 seconds ---
# 2010-01-28T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.977145671844482 seconds ---
# 2010-01-29T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.291357040405273 seconds ---
# 2010-02-01T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 9.06308889389038 seconds ---
# 2010-02-02T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.441651821136475 seconds ---
# 2010-02-03T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 8.660279035568237 seconds ---
# 2010-02-04T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.941373825073242 seconds ---
# 2010-02-05T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.581463098526001 seconds ---
# 2010-02-08T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.293684244155884 seconds ---
# 2010-02-09T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 7.32049298286438 seconds ---
# 2010-02-10T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.472572088241577 seconds ---
# 2010-02-11T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.360514879226685 seconds ---
# 2010-02-12T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.301586151123047 seconds ---
# 2010-02-16T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.5918357372283936 seconds ---
# 2010-02-17T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.837047100067139 seconds ---
# 2010-02-18T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.134732007980347 seconds ---
# 2010-02-19T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.7179059982299805 seconds ---
# 2010-02-22T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.207869052886963 seconds ---
# 2010-02-23T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.026020050048828 seconds ---
# 2010-02-24T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.467705249786377 seconds ---
# 2010-02-25T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.017564296722412 seconds ---
# 2010-02-26T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.3399858474731445 seconds ---
# 2010-03-01T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.477154731750488 seconds ---
# 2010-03-02T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 14.627422332763672 seconds ---
# 2010-03-03T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.6881959438323975 seconds ---
# 2010-03-04T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 8.734436988830566 seconds ---
# 2010-03-05T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.152346134185791 seconds ---
# 2010-03-08T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 7.079862117767334 seconds ---
# 2010-03-09T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.91991400718689 seconds ---
# 2010-03-10T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.263754844665527 seconds ---
# 2010-03-11T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.979189395904541 seconds ---
# 2010-03-12T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.919847011566162 seconds ---
# 2010-03-15T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.897762060165405 seconds ---
# 2010-03-16T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.514019012451172 seconds ---
# 2010-03-17T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.269412994384766 seconds ---
# 2010-03-18T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.551641225814819 seconds ---
# 2010-03-19T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.941358804702759 seconds ---
# 2010-03-22T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.581418037414551 seconds ---
# 2010-03-23T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.20602011680603 seconds ---
# 2010-03-24T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.389105796813965 seconds ---
# 2010-03-25T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.630445957183838 seconds ---
# 2010-03-26T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.401854991912842 seconds ---
# 2010-03-29T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.02416205406189 seconds ---
# 2010-03-30T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.99788498878479 seconds ---
# 2010-03-31T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.253133058547974 seconds ---
# 2010-04-01T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.30797004699707 seconds ---
# 2010-04-05T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.259198188781738 seconds ---
# 2010-04-06T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.447098731994629 seconds ---
# 2010-04-07T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.034873962402344 seconds ---
# 2010-04-08T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.145642042160034 seconds ---
# 2010-04-09T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 11.749067068099976 seconds ---
# 2010-04-12T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 8.848589181900024 seconds ---
# 2010-04-13T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.366796970367432 seconds ---
# 2010-04-14T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.0612406730651855 seconds ---
# 2010-04-15T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.1663079261779785 seconds ---
# 2010-04-16T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.494052171707153 seconds ---
# 2010-04-19T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.62827205657959 seconds ---
# 2010-04-20T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.477404832839966 seconds ---
# 2010-04-21T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.05628514289856 seconds ---
# 2010-04-22T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.8389270305633545 seconds ---
# 2010-04-23T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.773443937301636 seconds ---
# 2010-04-26T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.685041189193726 seconds ---
# 2010-04-27T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.47852897644043 seconds ---
# 2010-04-28T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.202083110809326 seconds ---
# 2010-04-29T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.854378938674927 seconds ---
# 2010-04-30T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.112807035446167 seconds ---
# 2010-05-03T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.609988212585449 seconds ---
# 2010-05-04T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.607378959655762 seconds ---
# 2010-05-05T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.765534162521362 seconds ---
# 2010-05-06T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.161916017532349 seconds ---
# 2010-05-07T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.565258026123047 seconds ---
# 2010-05-10T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.2111451625823975 seconds ---
# 2010-05-11T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.423374891281128 seconds ---
# 2010-05-12T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.245185136795044 seconds ---
# 2010-05-13T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.617645740509033 seconds ---
# 2010-05-14T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.8422839641571045 seconds ---
# 2010-05-17T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.63654899597168 seconds ---
# 2010-05-18T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.710131883621216 seconds ---
# 2010-05-19T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.545090913772583 seconds ---
# 2010-05-20T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.473602056503296 seconds ---
# 2010-05-21T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.283394813537598 seconds ---
# 2010-05-24T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.790058851242065 seconds ---
# 2010-05-25T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.2980637550354 seconds ---
# 2010-05-26T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.849344968795776 seconds ---
# 2010-05-27T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.9416821002960205 seconds ---
# 2010-05-28T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.576499938964844 seconds ---
# 2010-06-01T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.454661130905151 seconds ---
# 2010-06-02T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.6861701011657715 seconds ---
# 2010-06-03T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.926098108291626 seconds ---
# 2010-06-04T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.670918941497803 seconds ---
# 2010-06-07T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.085875988006592 seconds ---
# 2010-06-08T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.963748931884766 seconds ---
# 2010-06-09T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.471397876739502 seconds ---
# 2010-06-10T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.235350847244263 seconds ---
# 2010-06-11T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.626579761505127 seconds ---
# 2010-06-14T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.547122001647949 seconds ---
# 2010-06-15T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.408386945724487 seconds ---
# 2010-06-16T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.814881801605225 seconds ---
# 2010-06-17T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.104220867156982 seconds ---
# 2010-06-18T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.493772983551025 seconds ---
# 2010-06-21T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.227490186691284 seconds ---
# 2010-06-22T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.2784929275512695 seconds ---
# 2010-06-23T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.441637992858887 seconds ---
# 2010-06-24T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.633769989013672 seconds ---
# 2010-06-25T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.915086269378662 seconds ---
# 2010-06-28T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 11.291897058486938 seconds ---
# 2010-06-29T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.228931903839111 seconds ---
# 2010-06-30T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 7.318495988845825 seconds ---
# 2010-07-01T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.3896708488464355 seconds ---
# 2010-07-02T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.899389982223511 seconds ---
# 2010-07-06T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.690874814987183 seconds ---
# 2010-07-07T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.842461824417114 seconds ---
# 2010-07-08T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.56646990776062 seconds ---
# 2010-07-09T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.665953159332275 seconds ---
# 2010-07-12T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.491001844406128 seconds ---
# 2010-07-13T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.620203018188477 seconds ---
# 2010-07-14T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 3.8781991004943848 seconds ---
# 2010-07-15T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.854011058807373 seconds ---
# 2010-07-16T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.337147951126099 seconds ---
# 2010-07-19T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.3945958614349365 seconds ---
# 2010-07-20T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.080740928649902 seconds ---
# 2010-07-21T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.727614879608154 seconds ---
# 2010-07-22T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.823631048202515 seconds ---
# 2010-07-23T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 8.083789825439453 seconds ---
# 2010-07-26T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 8.353322982788086 seconds ---
# 2010-07-27T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 18.52214503288269 seconds ---
# 2010-07-28T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 21.0362229347229 seconds ---
# 2010-07-29T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 13.883327007293701 seconds ---
# 2010-07-30T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.397090911865234 seconds ---
# 2010-08-02T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.403231859207153 seconds ---
# 2010-08-03T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.364206075668335 seconds ---
# 2010-08-04T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.401623010635376 seconds ---
# 2010-08-05T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.968906879425049 seconds ---
# 2010-08-06T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 7.705619812011719 seconds ---
# 2010-08-09T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 8.943499088287354 seconds ---
# 2010-08-10T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 10.110568046569824 seconds ---
# 2010-08-11T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.819180011749268 seconds ---
# 2010-08-12T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.081516027450562 seconds ---
# 2010-08-13T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.872865915298462 seconds ---
# 2010-08-16T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.007981777191162 seconds ---
# 2010-08-17T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.2821831703186035 seconds ---
# 2010-08-18T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 7.224945783615112 seconds ---
# 2010-08-19T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.857000112533569 seconds ---
# 2010-08-20T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 9.208618879318237 seconds ---
# 2010-08-23T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.407445907592773 seconds ---
# 2010-08-24T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.294980049133301 seconds ---
# 2010-08-25T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 17.02618908882141 seconds ---
# 2010-08-26T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.055591821670532 seconds ---
# 2010-08-27T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.83315372467041 seconds ---
# 2010-08-30T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.89897894859314 seconds ---
# 2010-08-31T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 19.790400981903076 seconds ---
# 2010-09-01T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.270426034927368 seconds ---
# 2010-09-02T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.110074043273926 seconds ---
# 2010-09-03T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.72078013420105 seconds ---
# 2010-09-07T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.486352920532227 seconds ---
# 2010-09-08T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.682861089706421 seconds ---
# 2010-09-09T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.49633002281189 seconds ---
# 2010-09-10T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.253229856491089 seconds ---
# 2010-09-13T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.7305169105529785 seconds ---
# 2010-09-14T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.55751895904541 seconds ---
# 2010-09-15T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.9582459926605225 seconds ---
# 2010-09-16T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.340900182723999 seconds ---
# 2010-09-17T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.399446964263916 seconds ---
# 2010-09-20T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.938929796218872 seconds ---
# 2010-09-21T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.219107151031494 seconds ---
# 2010-09-22T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 16.8382568359375 seconds ---
# 2010-09-23T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.910165071487427 seconds ---
# 2010-09-24T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.2329630851745605 seconds ---
# 2010-09-27T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.933250665664673 seconds ---
# 2010-09-28T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.186784982681274 seconds ---
# 2010-09-29T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.554917097091675 seconds ---
# 2010-09-30T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.612847089767456 seconds ---
# 2010-10-01T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.253824949264526 seconds ---
# 2010-10-04T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.266480922698975 seconds ---
# 2010-10-05T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.792954206466675 seconds ---
# 2010-10-06T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# ...
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.85191798210144 seconds ---
# 2012-07-31T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.66377329826355 seconds ---
# 2012-08-01T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.408545017242432 seconds ---
# 2012-08-02T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.227543830871582 seconds ---
# 2012-08-03T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.6236042976379395 seconds ---
# 2012-08-06T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.862088918685913 seconds ---
# 2012-08-07T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 1204.0377418994904 seconds ---
# 2012-08-08T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.819857835769653 seconds ---
# 2012-08-09T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.689541816711426 seconds ---
# 2012-08-10T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.276751756668091 seconds ---
# 2012-08-13T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.04848313331604 seconds ---
# 2012-08-14T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.7835869789123535 seconds ---
# 2012-08-15T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.139675140380859 seconds ---
# 2012-08-16T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.156505823135376 seconds ---
# 2012-08-17T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.2704479694366455 seconds ---
# 2012-08-20T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.040696144104004 seconds ---
# 2012-08-21T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.1654112339019775 seconds ---
# 2012-08-22T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.2087931632995605 seconds ---
# 2012-08-23T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.5137927532196045 seconds ---
# 2012-08-24T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.169886827468872 seconds ---
# 2012-08-27T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.818223237991333 seconds ---
# 2012-08-28T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.946890830993652 seconds ---
# 2012-08-29T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.7891271114349365 seconds ---
# 2012-08-30T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.20461106300354 seconds ---
# 2012-08-31T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.087663888931274 seconds ---
# 2012-09-04T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.263044118881226 seconds ---
# 2012-09-05T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.50277304649353 seconds ---
# 2012-09-06T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.179421901702881 seconds ---
# 2012-09-07T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 10.179202795028687 seconds ---
# 2012-09-10T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.017277002334595 seconds ---
# 2012-09-11T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.024576902389526 seconds ---
# 2012-09-12T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.2806150913238525 seconds ---
# 2012-09-13T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 769.3493978977203 seconds ---
# 2012-09-14T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.218173980712891 seconds ---
# 2012-09-17T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.218907833099365 seconds ---
# 2012-09-18T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.2724831104278564 seconds ---
# 2012-09-19T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.70320987701416 seconds ---
# 2012-09-20T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 337.7882568836212 seconds ---
# 2012-09-21T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.717146158218384 seconds ---
# 2012-09-24T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.990361928939819 seconds ---
# 2012-09-25T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.950845956802368 seconds ---
# 2012-09-26T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.046551704406738 seconds ---
# 2012-09-27T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.928778886795044 seconds ---
# 2012-09-28T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.206654071807861 seconds ---
# 2012-10-01T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.704027891159058 seconds ---
# 2012-10-02T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.502017974853516 seconds ---
# 2012-10-03T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.647724151611328 seconds ---
# 2012-10-04T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.762286186218262 seconds ---
# 2012-10-05T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.244513034820557 seconds ---
# 2012-10-08T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.4644389152526855 seconds ---
# 2012-10-09T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.976411819458008 seconds ---
# 2012-10-10T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 7.5108489990234375 seconds ---
# 2012-10-11T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.367260932922363 seconds ---
# 2012-10-12T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.771255016326904 seconds ---
# 2012-10-15T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.572702884674072 seconds ---
# 2012-10-16T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.978830099105835 seconds ---
# 2012-10-17T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.775537729263306 seconds ---
# 2012-10-18T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 7.448039770126343 seconds ---
# 2012-10-19T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.010679006576538 seconds ---
# 2012-10-22T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.367587089538574 seconds ---
# 2012-10-23T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.154042959213257 seconds ---
# 2012-10-24T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.9351301193237305 seconds ---
# 2012-10-25T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 1631.0188689231873 seconds ---
# 2012-10-26T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 7.523038148880005 seconds ---
# 2012-10-31T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.6251068115234375 seconds ---
# 2012-11-01T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.189536094665527 seconds ---
# 2012-11-02T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.2134480476379395 seconds ---
# 2012-11-05T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.779026985168457 seconds ---
# 2012-11-06T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.7744340896606445 seconds ---
# 2012-11-07T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.218441963195801 seconds ---
# 2012-11-08T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.170351982116699 seconds ---
# 2012-11-09T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.2077813148498535 seconds ---
# 2012-11-12T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.02712607383728 seconds ---
# 2012-11-13T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.460289001464844 seconds ---
# 2012-11-14T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.971599817276001 seconds ---
# 2012-11-15T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.383385896682739 seconds ---
# 2012-11-16T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.503749132156372 seconds ---
# 2012-11-19T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.772387742996216 seconds ---
# 2012-11-20T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.535707950592041 seconds ---
# 2012-11-21T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.83516788482666 seconds ---
# 2012-11-23T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.806765079498291 seconds ---
# 2012-11-26T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.366804122924805 seconds ---
# 2012-11-27T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.6112120151519775 seconds ---
# 2012-11-28T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.684717893600464 seconds ---
# 2012-11-29T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.6969709396362305 seconds ---
# 2012-11-30T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.456567764282227 seconds ---
# 2012-12-03T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.441361904144287 seconds ---
# 2012-12-04T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.225498199462891 seconds ---
# 2012-12-05T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.5874199867248535 seconds ---
# 2012-12-06T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 5.039196014404297 seconds ---
# 2012-12-07T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 97.34522700309753 seconds ---
# 2012-12-10T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 10.86083197593689 seconds ---
# 2012-12-11T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.248137950897217 seconds ---
# 2012-12-12T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.650331020355225 seconds ---
# 2012-12-13T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.011764049530029 seconds ---
# 2012-12-14T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.486943960189819 seconds ---
# 2012-12-17T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.633172035217285 seconds ---
# 2012-12-18T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.844976902008057 seconds ---
# 2012-12-19T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.13729190826416 seconds ---
# 2012-12-20T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 4.932039737701416 seconds ---
# 2012-12-21T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 6.1978089809417725 seconds ---
# 2012-12-24T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.461747884750366 seconds ---
# 2012-12-26T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 4.899904012680054 seconds ---
# 2012-12-27T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 5.315151929855347 seconds ---

# %%
def clc_str_return(w, ret, str_name):
    w_i = np.zeros(len(ret.columns.tolist()))
    ret_str = pd.DataFrame(index = ret.index, columns=[str_name])
    for i in ret.index:
        ret_str.loc[i, str_name] = w_i@ret.loc[i,:]
        #ret_str.loc[i, str_name] = np.sum(w_i)
        if i in w.index:
            w_i = w.loc[i,:]
#             scalor = max(sum(w_i[w_i>0]), sum(-1 * w_i[w_i<0]))
#             w_i[w_i>0] = w_i[w_i>0]/scalor
#             w_i[w_i<0] = w_i[w_i<0]/scalor
#             w_i[w_i>0] = w_i[w_i>0]/sum(w_i[w_i>0])
#             w_i[w_i<0] = w_i[w_i<0]/sum(-1 * w_i[w_i<0])
     
    return ret_str

# %%
ret_str = clc_str_return(ptf['msr_w_cons'], ret, 'msr_w_cons')
ret_str = ret_str.join(clc_str_return(ptf['minvar_w_cons'], ret, 'minvar_w_cons'))

# %% [markdown]
# ## Compare with Benchmark

# %%
#ret_str.to_hdf(hdf_path, key = 'Portfolio_Plot', mode= 'a',data_columns = True, complib = 'zlib')
#ret_str = pd.read_hdf(hdf_path,key='Portfolio_Plot')

# %%
bnch_ret = (df_betas.groupby(['date']).apply(weighted_avg, 'ret', 'weightage_pct')+1).cumprod()
bnch_ret = bnch_ret.loc[(bnch_ret.index >= ret_str.index.min()) & (bnch_ret.index <= ret_str.index.max())]

# %%
rep_ = qs.reports.html(ret_str['msr_w_cons'],bnch_ret)
# Out:
# <script> var bl=new Blob(['<!-- generated by QuantStats for Python --><!DOCTYPE html><html lang="en"><head> <meta charset="utf-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"> <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"> <title>Tearsheet (generated by QuantStats)</title> <meta name="robots" content="noindex, nofollow"> <link rel="shortcut icon" href="https://qtpylib.io/favicon.ico" type="image/x-icon"> <style> body{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;margin:30px}body,p,table,td,th{font:13px/1.4 Arial,sans-serif}.container{max-width:960px;margin:auto}img,svg{width:100%}h1,h2,h3,h4{font-weight:400;margin:0}h1 dt{display:inline;margin-left:10px;font-size:14px}h3{margin-bottom:10px;font-weight:700}h4{color:grey}h4 a{color:#09c;text-decoration:none}h4 a:hover{color:#069;text-decoration:underline}hr{margin:25px 0 40px;height:0;border:0;border-top:1px solid #ccc}#left{width:620px;margin-right:18px;margin-top:-1.2rem;float:left}#right{width:320px;float:right}#left svg{margin:-1.5rem 0}#monthly_heatmap{overflow:hidden}#monthly_heatmap svg{margin:-1.5rem 0}table{margin:0 0 40px;border:0;border-spacing:0;width:100%}table td,table th{text-align:right;padding:4px 5px 3px 5px}table th{text-align:right;padding:6px 5px 5px 5px}table td:first-of-type,table th:first-of-type{text-align:left;padding-left:2px}table td:last-of-type,table th:last-of-type{text-align:right;padding-right:2px}td hr{margin:5px 0}table th{font-weight:400}table thead th{font-weight:700;background:#eee}#eoy table td:after{content:"%"}#eoy table td:first-of-type:after,#eoy table td:last-of-type:after,#eoy table td:nth-of-type(4):after{content:""}#eoy table th{text-align:right}#eoy table th:first-of-type{text-align:left}#eoy table td:after{content:"%"}#eoy table td:first-of-type:after,#eoy table td:last-of-type:after{content:""}#ddinfo table td:nth-of-type(3):after{content:"%"}#ddinfo table th{text-align:right}#ddinfo table td:first-of-type,#ddinfo table td:nth-of-type(2),#ddinfo table th:first-of-type,#ddinfo table th:nth-of-type(2){text-align:left}#ddinfo table td:nth-of-type(3):after{content:"%"} @media print{hr{margin:25px 0}body{margin:0}.container{max-width:100%;margin:0}#left{width:55%;margin:0}#left svg{margin:0 0 -10%}#left svg:first-of-type{margin-top:-30%}#right{margin:0;width:45%}} </style></head><body onload="save()"> <div class="container"> <h1>Strategy Tearsheet <dt> 1 Dec, 2010 - 26 Dec, 2012</dt></h1> <h4>Generated by <a href="http://quantstats.io" target="quantstats">QuantStats</a> (v. 0.0.50)</h4> <hr> <div id="left"> <div> <?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="360pt" version="1.1" viewBox="0 0 576 360" width="576pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <metadata> <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"> <cc:Work> <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/> <dc:date>2022-03-29T19:22:06.111017</dc:date> <dc:format>image/svg+xml</dc:format> <dc:creator> <cc:Agent> <dc:title>Matplotlib v3.3.2, https://matplotlib.org/</dc:title> </cc:Agent> </dc:creator> </cc:Work> </rdf:RDF> </metadata> <defs> <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style> </defs> <g id="figure_1"> <g id="patch_1"> <path d="M 0 360 L 576 360 L 576 0 L 0 0 z" style="fill:#ffffff;"/> </g> <g id="axes_1"> <g id="patch_2"> <path d="M 44.675 308.664746 L 565.2 308.664746 L 565.2 51.8 L 44.675 51.8 z" style="fill:#ffffff;"/> </g> <g id="matplotlib.axis_1"> <g id="xtick_1"> <g id="line2d_1"> <path clip-path="url(#p8987549fb2)" d="M 87.739117 308.664746 L 87.739117 51.8 " style="fill:none;stroke:#dddddd;stroke-linecap:round;stro ...

# %%
dd_ = qs.reports.html(ret_str['minvar_w_cons'],bnch_ret)
# Out:
# <script> var bl=new Blob(['<!-- generated by QuantStats for Python --><!DOCTYPE html><html lang="en"><head> <meta charset="utf-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"> <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"> <title>Tearsheet (generated by QuantStats)</title> <meta name="robots" content="noindex, nofollow"> <link rel="shortcut icon" href="https://qtpylib.io/favicon.ico" type="image/x-icon"> <style> body{-webkit-font-smoothing:antialiased;-moz-osx-font-smoothing:grayscale;margin:30px}body,p,table,td,th{font:13px/1.4 Arial,sans-serif}.container{max-width:960px;margin:auto}img,svg{width:100%}h1,h2,h3,h4{font-weight:400;margin:0}h1 dt{display:inline;margin-left:10px;font-size:14px}h3{margin-bottom:10px;font-weight:700}h4{color:grey}h4 a{color:#09c;text-decoration:none}h4 a:hover{color:#069;text-decoration:underline}hr{margin:25px 0 40px;height:0;border:0;border-top:1px solid #ccc}#left{width:620px;margin-right:18px;margin-top:-1.2rem;float:left}#right{width:320px;float:right}#left svg{margin:-1.5rem 0}#monthly_heatmap{overflow:hidden}#monthly_heatmap svg{margin:-1.5rem 0}table{margin:0 0 40px;border:0;border-spacing:0;width:100%}table td,table th{text-align:right;padding:4px 5px 3px 5px}table th{text-align:right;padding:6px 5px 5px 5px}table td:first-of-type,table th:first-of-type{text-align:left;padding-left:2px}table td:last-of-type,table th:last-of-type{text-align:right;padding-right:2px}td hr{margin:5px 0}table th{font-weight:400}table thead th{font-weight:700;background:#eee}#eoy table td:after{content:"%"}#eoy table td:first-of-type:after,#eoy table td:last-of-type:after,#eoy table td:nth-of-type(4):after{content:""}#eoy table th{text-align:right}#eoy table th:first-of-type{text-align:left}#eoy table td:after{content:"%"}#eoy table td:first-of-type:after,#eoy table td:last-of-type:after{content:""}#ddinfo table td:nth-of-type(3):after{content:"%"}#ddinfo table th{text-align:right}#ddinfo table td:first-of-type,#ddinfo table td:nth-of-type(2),#ddinfo table th:first-of-type,#ddinfo table th:nth-of-type(2){text-align:left}#ddinfo table td:nth-of-type(3):after{content:"%"} @media print{hr{margin:25px 0}body{margin:0}.container{max-width:100%;margin:0}#left{width:55%;margin:0}#left svg{margin:0 0 -10%}#left svg:first-of-type{margin-top:-30%}#right{margin:0;width:45%}} </style></head><body onload="save()"> <div class="container"> <h1>Strategy Tearsheet <dt> 1 Dec, 2010 - 26 Dec, 2012</dt></h1> <h4>Generated by <a href="http://quantstats.io" target="quantstats">QuantStats</a> (v. 0.0.50)</h4> <hr> <div id="left"> <div> <?xml version="1.0" encoding="utf-8" standalone="no"?><!DOCTYPE svg PUBLIC "-//W3C//DTD SVG 1.1//EN" "http://www.w3.org/Graphics/SVG/1.1/DTD/svg11.dtd"><!-- Created with matplotlib (https://matplotlib.org/) --><svg height="360pt" version="1.1" viewBox="0 0 576 360" width="576pt" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"> <metadata> <rdf:RDF xmlns:cc="http://creativecommons.org/ns#" xmlns:dc="http://purl.org/dc/elements/1.1/" xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#"> <cc:Work> <dc:type rdf:resource="http://purl.org/dc/dcmitype/StillImage"/> <dc:date>2022-03-29T19:22:13.339401</dc:date> <dc:format>image/svg+xml</dc:format> <dc:creator> <cc:Agent> <dc:title>Matplotlib v3.3.2, https://matplotlib.org/</dc:title> </cc:Agent> </dc:creator> </cc:Work> </rdf:RDF> </metadata> <defs> <style type="text/css">*{stroke-linecap:butt;stroke-linejoin:round;}</style> </defs> <g id="figure_1"> <g id="patch_1"> <path d="M 0 360 L 576 360 L 576 0 L 0 0 z" style="fill:#ffffff;"/> </g> <g id="axes_1"> <g id="patch_2"> <path d="M 44.675 308.664746 L 565.2 308.664746 L 565.2 51.8 L 44.675 51.8 z" style="fill:#ffffff;"/> </g> <g id="matplotlib.axis_1"> <g id="xtick_1"> <g id="line2d_1"> <path clip-path="url(#p5fd277d381)" d="M 87.739117 308.664746 L 87.739117 51.8 " style="fill:none;stroke:#dddddd;stroke-linecap:round;stro ...

# %% [markdown]
# ## Test Set Predictions
#
# The function is only different so that it also normalizes the rolling window we are fitting/testing on .This is important so we avoid lookahead bias in our test set.

# %%
def Rolling_Forest_Test(data,predictors,target,window,params):

# First we form the window 
    start_window = data.date.min()
    end_window = data.date.min() + BDay(window)
    pred_date = end_window + BDay(1)

#Auxiliary placeholders and reg. constant
    data = data.sort_values(by=['date','permno'])
    predictions_df = pd.DataFrame(index=[pred_date], columns=np.sort(data.permno.unique()))
    scores = []
    missing_dates = []

# The train / predict loop
    while pred_date <= data.date.max():
# The loop will go through business days, not necessarily trading days (hence the try clause).        
        try:
        # Picking the window of data to train and instantiating the predictor model
            mask = ((data['date'] >= start_window) & (data['date'] <= end_window))
            train_window = data[mask].set_index('permno')
            train_window = process(train_window,list(predictors)[1:])
            linreg = RandomForestRegressor(**params)
        # Fitting the model on the training window     
            fit_ = linreg.fit(train_window[list(predictors)],train_window[target])
        # Predicting for each permno on the next day after fit    
            predi_df = data[data['date']== pred_date].loc[:,list(predictors)+['permno']].set_index('permno')
            predi = fit_.predict(predi_df)
        # Storing in a useful format for backtest
            one_predi = (pd.DataFrame(data = predi, index=predi_df.index,columns=[pred_date])).T
            predictions_df = pd.concat([predictions_df,one_predi], axis=0, ignore_index=False)
       # R^2 to help visualize training performance     
            score_r2 = linreg.score(predi_df[list(predictors)], data[data['date']== pred_date][target])
            scores.append(score_r2)
        except:
            missing_dates.append(pred_date)
# Update window position        
        start_window = start_window + BDay(1)
        end_window = start_window + BDay(window)
        pred_date = end_window + BDay(1)
# Real returns we will need

    # real_returns = data.pivot_table(index='date', columns='permno', values='fret1d')
    real_returns = data.pivot(index='date', columns='permno', values='fret1d')
   # r2_average = np.mean(scores)
    
    return real_returns, predictions_df[1:], missing_dates,scores #, r2_average
    # return data

# %%
params_forest = {
    "n_estimators": 30,
    'max_features':'sqrt', 
    'max_depth':5,
    'min_samples_leaf':3,
    'min_samples_split':4,
    'random_state':1001,
    }

#test.insert(10, 'constant', 1.0)# MAKE SURE TO RUN IF NOT ALREADY INSERTED IN GRIDSEARCH !
regressors = test.columns[10:-1]
target = ['fret1d']

real_returns_forest_test, expected_returns_forest_test, missing_dates_forest_test, scores_forest_test = Rolling_Forest_Test(data=test, 
                                                              predictors=regressors,
                                                              target=target, 
                                                              window=21,
                                                              params=params_forest)
real_returns_forest_test = real_returns_forest_test[real_returns_forest_test.index >= expected_returns_forest_test.index.min()]

# %%
ret, expret = prepare_returns(real_returns_forest_test,expected_returns_forest_test,pd.datetime(2019, 12, 31),9)

# %%
dtall = pd.DataFrame(index = ret.index, data = ret.index, columns = ['dates']) #
dt_m = dtall.groupby(pd.Grouper(freq='B')).last() # We can rebalane daily for final solution should be better results
dates_rebal = dt_m.index.values # But less realistic (daily trading)

 # We need to also exclude from rebalance dates the business days that were actually not trading days
# #missing_dates = [i.to_datetime64() for i in missing_dates] # Uncomment if needed a convert!
dates_rebal = [x for x in dates_rebal if x not in missing_dates_forest_test]

#dates_ = [i.date() for i in dates_rebal]
real_returns_forest_test = real_returns_forest_test.loc[~real_returns_forest_test.index.isin(missing_dates_forest_test)]
expected_returns_forest_test = expected_returns_forest_test.loc[~expected_returns_forest_test.index.isin(missing_dates_forest_test)]

# %%
names = ret.columns
ptf = {} 

# Initiate a dictionary of placeholders for the 3 strategies
ptf['msr_w_cons'] = pd.DataFrame(data = 0.0, index = dates_rebal, columns = names)
ptf['minvar_w_cons'] = pd.DataFrame(data = 0.0, index = dates_rebal, columns = names)

# %%
# Optimization rutine for the 2 minimization problems and for the closed form solution
st_point_msr = None
st_point_mvp = None

for d in dates_rebal: 
    print(d)    
    start_time = time.time()

    ret, expret = prepare_returns(real_returns_forest_test,expected_returns_forest_test,d,3)

    # we prepare inputs:
    cov,mu,cons,bounds = configure_inputs_for_optimisation(test, ret, expret, d, 0.05,21)

    # define starting point
    if st_point_msr is None:
        st_point_msr = np.ones(ret.columns.size)/ret.columns.size
    if st_point_mvp is None:
        st_point_mvp = np.ones(ret.columns.size)/ret.columns.size

    # run optimisation, MSR
    res = minimize(MSR,
                st_point_msr,
                args = (cov, mu), 
                constraints = cons, 
                bounds = bounds, 
                method = 'SLSQP',
                options={'ftol': 1e-16, 'disp': False})
    print("MSR: " + res.message)
    
    st_point_msr = res.x

    # store results
#     i = 0
#     for col in ret.columns:
#         ptf['msr_w_cons'].loc[d, col] = res.x[i]
#         i += 1
    ptf['msr_w_cons'].loc[d] = res.x
    
    res = minimize(MVP,
                st_point_mvp,
                args = (cov, mu), 
                constraints = cons, 
                bounds = bounds, 
                method = 'SLSQP',
                options={'ftol': 1e-16, 'disp': False})
    
    print("MVP: " + res.message)
    ptf['minvar_w_cons'].loc[d] = res.x

    # Set next starting point
    st_point_mvp = res.x

    
    print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# 2013-10-14T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 12.590938806533813 seconds ---
# 2013-10-15T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.260168075561523 seconds ---
# 2013-10-16T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 13.21164584159851 seconds ---
# 2013-10-17T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 13.244446039199829 seconds ---
# 2013-10-18T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Positive directional derivative for linesearch
# --- 12.138653993606567 seconds ---
# 2013-10-21T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 15.677916049957275 seconds ---
# 2013-10-22T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 13.23788595199585 seconds ---
# 2013-10-23T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 12.554646015167236 seconds ---
# 2013-10-24T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 10.815787076950073 seconds ---
# 2013-10-25T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 13.122883081436157 seconds ---
# 2013-10-28T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Positive directional derivative for linesearch
# --- 12.208414793014526 seconds ---
# 2013-10-29T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 11.291364908218384 seconds ---
# 2013-10-30T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 16.920814037322998 seconds ---
# 2013-10-31T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 10.477492094039917 seconds ---
# 2013-11-01T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 13.751389741897583 seconds ---
# 2013-11-04T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 14.365885972976685 seconds ---
# 2013-11-05T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 12.42849087715149 seconds ---
# 2013-11-06T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Positive directional derivative for linesearch
# --- 11.48096776008606 seconds ---
# 2013-11-07T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 12.934448957443237 seconds ---
# 2013-11-08T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 12.873063325881958 seconds ---
# 2013-11-11T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 12.497125148773193 seconds ---
# 2013-11-12T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Positive directional derivative for linesearch
# --- 11.7914719581604 seconds ---
# 2013-11-13T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 10.139692783355713 seconds ---
# 2013-11-14T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 15.133535146713257 seconds ---
# 2013-11-15T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 9.578083276748657 seconds ---
# 2013-11-18T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 12.696940183639526 seconds ---
# 2013-11-19T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 12.455481767654419 seconds ---
# 2013-11-20T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 8.322234153747559 seconds ---
# 2013-11-21T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 9.991137981414795 seconds ---
# 2013-11-22T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 12.57687497138977 seconds ---
# 2013-11-25T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 12.434683799743652 seconds ---
# 2013-11-26T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 13.338741064071655 seconds ---
# 2013-11-27T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 18.519407749176025 seconds ---
# 2013-11-29T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.29506516456604 seconds ---
# 2013-12-02T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 10.135370969772339 seconds ---
# 2013-12-03T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 14.197641849517822 seconds ---
# 2013-12-04T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 12.06623888015747 seconds ---
# 2013-12-05T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 10.039361715316772 seconds ---
# 2013-12-06T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 12.444720029830933 seconds ---
# 2013-12-09T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.180328130722046 seconds ---
# 2013-12-10T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 9.097580194473267 seconds ---
# 2013-12-11T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 12.29035997390747 seconds ---
# 2013-12-12T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 10.257354974746704 seconds ---
# 2013-12-13T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 14.129603862762451 seconds ---
# 2013-12-16T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 13.699793338775635 seconds ---
# 2013-12-17T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 8.703938961029053 seconds ---
# 2013-12-18T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 12.642198085784912 seconds ---
# 2013-12-19T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.43165111541748 seconds ---
# 2013-12-20T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 12.935785055160522 seconds ---
# 2013-12-23T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 13.525995016098022 seconds ---
# 2013-12-24T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 9.485160112380981 seconds ---
# 2013-12-26T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 9.420440196990967 seconds ---
# 2013-12-27T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 8.220927953720093 seconds ---
# 2013-12-30T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.359816074371338 seconds ---
# 2013-12-31T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.496965885162354 seconds ---
# 2014-01-02T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 13.053641080856323 seconds ---
# 2014-01-03T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 12.55314302444458 seconds ---
# 2014-01-06T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 12.955178022384644 seconds ---
# 2014-01-07T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 13.181655168533325 seconds ---
# 2014-01-08T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Positive directional derivative for linesearch
# --- 15.374349117279053 seconds ---
# 2014-01-09T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 8.030827045440674 seconds ---
# 2014-01-10T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 12.502908945083618 seconds ---
# 2014-01-13T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 12.605780124664307 seconds ---
# 2014-01-14T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 13.27506709098816 seconds ---
# 2014-01-15T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 11.613719940185547 seconds ---
# 2014-01-16T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Positive directional derivative for linesearch
# --- 12.311189651489258 seconds ---
# 2014-01-17T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 12.4931058883667 seconds ---
# 2014-01-21T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Positive directional derivative for linesearch
# --- 10.364212036132812 seconds ---
# 2014-01-22T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 13.548008918762207 seconds ---
# 2014-01-23T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 13.248209953308105 seconds ---
# 2014-01-24T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 12.82231593132019 seconds ---
# 2014-01-27T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 17.626129865646362 seconds ---
# 2014-01-28T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 13.247951984405518 seconds ---
# 2014-01-29T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.119457006454468 seconds ---
# 2014-01-30T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 10.08462381362915 seconds ---
# 2014-01-31T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 13.464094877243042 seconds ---
# 2014-02-03T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 11.592982053756714 seconds ---
# 2014-02-04T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 9.316885948181152 seconds ---
# 2014-02-05T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 8.615209341049194 seconds ---
# 2014-02-06T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Positive directional derivative for linesearch
# --- 8.25622010231018 seconds ---
# 2014-02-07T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.774504899978638 seconds ---
# 2014-02-10T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 10.932264804840088 seconds ---
# 2014-02-11T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Positive directional derivative for linesearch
# --- 12.475804328918457 seconds ---
# 2014-02-12T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 6.9699180126190186 seconds ---
# 2014-02-13T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 12.898120880126953 seconds ---
# 2014-02-14T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 9.410500049591064 seconds ---
# 2014-02-18T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Positive directional derivative for linesearch
# --- 12.085407018661499 seconds ---
# 2014-02-19T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 12.659348964691162 seconds ---
# 2014-02-20T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Positive directional derivative for linesearch
# --- 11.668751955032349 seconds ---
# 2014-02-21T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 11.122323989868164 seconds ---
# 2014-02-24T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 12.467411041259766 seconds ---
# 2014-02-25T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Optimization terminated successfully.
# --- 8.915272951126099 seconds ---
# 2014-02-26T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 7.737712144851685 seconds ---
# 2014-02-27T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 13.238452911376953 seconds ---
# 2014-02-28T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Iteration limit exceeded
# --- 554.3360283374786 seconds ---
# 2014-03-03T00:00:00.000000000
# MSR: Positive directional derivative for linesearch
# MVP: Optimization terminated successfully.
# --- 12.293978929519653 seconds ---
# 2014-03-04T00:00:00.000000000
# MSR: Inequality constraints incompatible
# MVP: Iteration limit exceeded
# --- 14.612584114074707 seconds ---
# 2014-03-05T00:00:00.000000000
# MSR: Positive directional derivative for linesearch

# %%
ptf['msr_w_cons']

# %%
def clc_str_return(w, ret, str_name):
    w_i = np.zeros(len(ret.columns.tolist()))
    ret_str = pd.DataFrame(index = ret.index, columns=[str_name])
    for i in ret.index:
        ret_str.loc[i, str_name] = w_i@ret.loc[i,:]
        #ret_str.loc[i, str_name] = np.sum(w_i)
        if i in w.index:
            w_i = w.loc[i,:]
#             scalor = max(sum(w_i[w_i>0]), sum(-1 * w_i[w_i<0]))
#             w_i[w_i>0] = w_i[w_i>0]/scalor
#             w_i[w_i<0] = w_i[w_i<0]/scalor
#             w_i[w_i>0] = w_i[w_i>0]/sum(w_i[w_i>0])
#             w_i[w_i<0] = w_i[w_i<0]/sum(-1 * w_i[w_i<0])
     
    return ret_str

# %%
ret, expret = prepare_returns(real_returns_forest_test,expected_returns_forest_test,pd.datetime(2019, 12, 31),9)
ret_str = clc_str_return(ptf['msr_w_cons'], ret, 'msr_w_cons')
ret_str = ret_str.join(clc_str_return(ptf['minvar_w_cons'], ret, 'minvar_w_cons'))

# %%
bnch_ret = (df_betas.groupby(['date']).apply(weighted_avg, 'ret', 'weightage_pct')+1).cumprod()
bnch_ret = bnch_ret.loc[(bnch_ret.index >= ret_str.index.min()) & (bnch_ret.index <= ret_str.index.max())]
bnch_ret = bnch_ret.loc[bnch_ret.index.isin(ret_str['msr_w_cons'].index)]

# %%
rep_ = qs.reports.html(ret_str['msr_w_cons'],bnch_ret)

# %%
rep_ = qs.reports.html(ret_str['minvar_w_cons'],bnch_ret)
